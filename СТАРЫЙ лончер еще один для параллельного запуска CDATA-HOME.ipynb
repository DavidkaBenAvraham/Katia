# %%
import main

suppliers_names = ['cdata','mor','grand','vdg']
one_supplier = ['cdata']

scenario = ["cdata_categories_aio_asus.json",
            "cdata_categories_aio_dell.json",
            "cdata_categories_aio_hp.json"]

scenario = ["cdata_categories_video.json","cdata_categories_webcams.json"]
scenario = [ "cdata_categories_laptops_dell.json",
    "cdata_categories_laptops_hp.json",
    "cdata_categories_gaming_laptops_asus.json",
    "cdata_categories_gaming_laptops_dell.json",
    "cdata_categories_gaming_laptops_hp.json",
    "cdata_categories_monitors_apple.json",
    "cdata_categories_monitors_dell.json",
    "cdata_categories_monitors_hp.json",
    "cdata_categories_printers.json",
    "cdata_categories_workstatios.json",
    "cdata_categories_webcams.json",
    "cdata_categories_ups.json",
    "cdata_categories_video.json"]


desktops = ["cdata_categories_desktops.json",
            "cdata_categories_gaming_desktops.json" , 
            "cdata_categories_workstatios.json"]
laptops = [ "cdata_categories_laptops_asus.json",
    "cdata_categories_laptops_dell.json",
    "cdata_categories_laptops_hp.json", 
    "cdata_categories_gaming_laptops_asus.json",
    "cdata_categories_gaming_laptops_dell.json",
    "cdata_categories_gaming_laptops_hp.json"]

monitors = [ "cdata_categories_monitors_apple.json",
    "cdata_categories_monitors_dell.json",
    "cdata_categories_monitors_hp.json"]

printers = ["cdata_categories_printers.json"]

webcams = ["cdata_categories_webcams.json"]

video = ["cdata_categories_video.json"]

ups = ["cdata_categories_ups.json"]


scenaries = [desktops , laptops , monitors , printers , webcams , video  , ups]


for scenario in scenaries: 
    supplier = main.run_supplier('cdata')
    main.run_scenario(supplier , scenario)
# Out:
# 2021-02-05 11:29:16.441786 (delta = 0:00:00.000997) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс Driver()
# 2021-02-05 11:29:25.837499 (delta = 0:00:09.395713) 	 : 	 run_supplier->__init__->write:
#         LOG STR:  запустился класс Cdata
# 2021-02-05 11:29:32.309124 (delta = 0:00:06.471625) 	 : 	 run->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.c-data.co.il/
#             Title : C-Data
# 2021-02-05 11:29:34.839772 (delta = 0:00:02.530648) 	 : 	 logged_in->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/Login
#             Title : C-Data. כניסה
# 2021-02-05 11:29:39.122875 (delta = 0:00:04.283103) 	 : 	 run->logged_in->write:
#         LOG STR:  C-data logged in
# 2021-02-05 11:29:42.012113 (delta = 0:00:02.889238) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/%D7%9E%D7%97%D7%A9%D7%91%D7%99%D7%9D-%D7%A0%D7%99%D7%99%D7%97%D7%99%D7%9D#/specFilters=227m!#-!4633
#             Title : C-Data. מחשבים נייחים
# 2021-02-05 11:29:43.763203 (delta = 0:00:01.751090) 	 : 	 sozdaj_ssylki_na_tovary->sozdaj_spisok_ssylok_na_stranicy_tovarov_so_stranicy_kategorii->write:
#         LOG STR:   Собрал со страницы категории ссылки на товары:
#     ['https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hdwin10pro-64bwifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hdwin10pro-64bwifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hdwin10pro-64bwifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os', 'https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os', 'https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os', 'https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os', 'https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os', 'https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os', 'https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os', 'https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw', 'https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw', 'https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw', 'https://reseller.c-data.co.il/hp290-g4-mti3-101008gb256gb-win-10-pro1yw', 'https://reseller.c-data.co.il/hp290-g4-mti3-101008gb256gb-win-10-pro1yw', 'https://reseller.c-data.co.il/hp290-g4-mti3-101008gb256gb-win-10-pro1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw']
# 2021-02-05 11:29:59.294328 (delta = 0:00:15.531125) 	 : 	 click_to_next_page->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', 'li.next-page a')
# 2021-02-05 11:29:59.300399 (delta = 0:00:00.006071) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки ['https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hdwin10pro-64bwifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hdwin10pro-64bwifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hdwin10pro-64bwifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os', 'https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os', 'https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os', 'https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os', 'https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os', 'https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os', 'https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os', 'https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw', 'https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw', 'https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw', 'https://reseller.c-data.co.il/hp290-g4-mti3-101008gb256gb-win-10-pro1yw', 'https://reseller.c-data.co.il/hp290-g4-mti3-101008gb256gb-win-10-pro1yw', 'https://reseller.c-data.co.il/hp290-g4-mti3-101008gb256gb-win-10-pro1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw']
# 2021-02-05 11:29:59.301430 (delta = 0:00:00.001031) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   собранны ссылки на товары : ['https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw', 'https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os', 'https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw', 'https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os', 'https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os', 'https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os', 'https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hdwin10pro-64bwifi3y-os', 'https://reseller.c-data.co.il/hp290-g4-mti3-101008gb256gb-win-10-pro1yw']
# 2021-02-05 11:30:01.204790 (delta = 0:00:01.903360) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdfree-dos1yw
#             Title : C-Data. HP260 G4 DM i3-10110U/8GB/256GB SSD/FREE DOS/1yw
# 2021-02-05 11:30:01.420214 (delta = 0:00:00.215424) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku 23H26EA#ABT ---
# 2021-02-05 11:30:01.452131 (delta = 0:00:00.031917) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $364.00
#
# 2021-02-05 11:30:01.591754 (delta = 0:00:00.139623) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена до округления 1490.58
# 2021-02-05 11:30:01.593750 (delta = 0:00:00.001996) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена после округления 1490
# 2021-02-05 11:30:02.521311 (delta = 0:00:00.927561) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = 23H26EA#ABT
# 2021-02-05 11:30:02.579157 (delta = 0:00:00.057846) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,91,89,231,235', 'Supplier Reference': '23H26EA#ABT', 'Reference': 'CDT-23H26EA#ABT', 'manufacrurer reference': '23H26EA#ABT', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'HP260 G4 DM I3-10110U/8GB/256GB SSD/FREE DOS/1YW', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '1490', 'Supplier Price (Tax Excl.)': '364.0', 'brand': 'HP', 'Short Description': 'HP260 G4 DM i3-10110U/8GB/256GB SSD/FREE DOS/1yw', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">HP 260 G4                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">23H26EAABT                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10110U Processor (4M Cache, up to 4.10 GHz)                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Free Dos                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O</strong><br role="presentation">Headphone/microphone combo<br role="presentation">SuperSpeed USB Type-C® 10Gbps signaling rate<br role="presentation">SuperSpeed USB Type-A 5Gbpssignaling rate<br role="presentation">USB Type-A 480Mbps signaling rate</p><p data-andiallelmwithtext="16"><br role="presentation"><strong data-andiallelmwithtext="16">Rear I/O</strong><br role="presentation">RJ-45<br role="presentation">VGA<br role="presentation">serial<br role="presentation">HDMI 1.4<br role="presentation">2xSuper ...
# 2021-02-05 11:30:02.581152 (delta = 0:00:00.001995) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data {'category': '1,2,91,89,231,235', 'Supplier Reference': '23H26EA#ABT', 'Reference': 'CDT-23H26EA#ABT', 'manufacrurer reference': '23H26EA#ABT', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'HP260 G4 DM I3-10110U/8GB/256GB SSD/FREE DOS/1YW', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '1490', 'Supplier Price (Tax Excl.)': '364.0', 'brand': 'HP', 'Short Description': 'HP260 G4 DM i3-10110U/8GB/256GB SSD/FREE DOS/1yw', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">HP 260 G4                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">23H26EAABT                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10110U Processor (4M Cache, up to 4.10 GHz)                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Free Dos                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O</strong><br role="presentation">Headphone/microphone combo<br role="presentation">SuperSpeed USB Type-C® 10Gbps signaling rate<br role="presentation">SuperSpeed USB Type-A 5Gbpssignaling rate<br role="presentation">USB Type-A 480Mbps signaling rate</p><p data-andiallelmwithtext="16"><br role="presentation"><strong data-andiallelmwithtext="16">Rear I/O</strong><br role="presentation">RJ-45<br role="presentation">VGA<br role="presentation">serial<br role="presentation">HDMI 1.4<br role="presentation">2xSup ...
# 2021-02-05 11:30:02.582149 (delta = 0:00:00.000997) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2021-02-05 11:30:04.700251 (delta = 0:00:02.118102) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/dell-optiplex-3080-mt-i3-103008gb256ssdintel-hdrwdos3y-os
#             Title : C-Data. Dell OPTIPLEX 3080 MT I3-10300/8GB/256SSD/INTEL HD/RW/DOS/3Y-OS
# 2021-02-05 11:30:04.879993 (delta = 0:00:00.179742) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku OP3080-1045 ---
# 2021-02-05 11:30:04.952797 (delta = 0:00:00.072804) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $532.00
#
# 2021-02-05 11:30:05.015629 (delta = 0:00:00.062832) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена до округления 2178.54
# 2021-02-05 11:30:05.016640 (delta = 0:00:00.001011) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена после округления 2180
# 2021-02-05 11:30:06.071706 (delta = 0:00:01.055066) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = OP3080-1045
# 2021-02-05 11:30:06.102660 (delta = 0:00:00.030954) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,91,89,231,235', 'Supplier Reference': 'OP3080-1045', 'Reference': 'CDT-OP3080-1045', 'manufacrurer reference': 'OP3080-1045', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'DELL OPTIPLEX 3080 MT I3-10300/8GB/256SSD/INTEL HD/RW/DOS/3Y-OS', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '2180', 'Supplier Price (Tax Excl.)': '532.0', 'brand': 'HP', 'Short Description': 'Dell OPTIPLEX 3080 MT I3-10300/8GB/256SSD/INTEL HD/RW/DOS/3Y-OS', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Dell OPTIPLEX 3080 MT                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">OP3080-1045                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10300, 8MB Cache, 3.7 GHz to 4.4 GHz                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB DDR4                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Free Dos                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                קישוריות                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">802.11ac dual band 2x2 + Bluetooth                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O<br role="presentation"></strong>2xUSB 2.0 Type-A<br role="presentation">2xUSB 3.2 Gen 1 Type-A<br role ...
# 2021-02-05 11:30:06.103623 (delta = 0:00:00.000963) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data {'category': '1,2,91,89,231,235', 'Supplier Reference': 'OP3080-1045', 'Reference': 'CDT-OP3080-1045', 'manufacrurer reference': 'OP3080-1045', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'DELL OPTIPLEX 3080 MT I3-10300/8GB/256SSD/INTEL HD/RW/DOS/3Y-OS', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '2180', 'Supplier Price (Tax Excl.)': '532.0', 'brand': 'HP', 'Short Description': 'Dell OPTIPLEX 3080 MT I3-10300/8GB/256SSD/INTEL HD/RW/DOS/3Y-OS', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Dell OPTIPLEX 3080 MT                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">OP3080-1045                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10300, 8MB Cache, 3.7 GHz to 4.4 GHz                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB DDR4                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Free Dos                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                קישוריות                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">802.11ac dual band 2x2 + Bluetooth                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O<br role="presentation"></strong>2xUSB 2.0 Type-A<br role="presentation">2xUSB 3.2 Gen 1 Type-A<br ro ...
# 2021-02-05 11:30:06.104622 (delta = 0:00:00.000999) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2021-02-05 11:30:07.852247 (delta = 0:00:01.747625) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/hp260-g4-dm-i3-10110u8gb256gb-ssdwifistandw10p641yw
#             Title : C-Data. HP260 G4 DM I3-10110U/8GB/256GB SSD/WIFI/Stand/W10p64/1yw
# 2021-02-05 11:30:08.001753 (delta = 0:00:00.149506) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku 23G84EA#ABT ---
# 2021-02-05 11:30:08.022697 (delta = 0:00:00.020944) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $499.00
#
# 2021-02-05 11:30:08.100272 (delta = 0:00:00.077575) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена до округления 2043.405
# 2021-02-05 11:30:08.102268 (delta = 0:00:00.001996) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена после округления 2040
# 2021-02-05 11:30:09.144186 (delta = 0:00:01.041918) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = 23G84EA#ABT
# 2021-02-05 11:30:09.186074 (delta = 0:00:00.041888) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,91,89,231,235', 'Supplier Reference': '23G84EA#ABT', 'Reference': 'CDT-23G84EA#ABT', 'manufacrurer reference': '23G84EA#ABT', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'HP260 G4 DM I3-10110U/8GB/256GB SSD/WIFI/STAND/W10P64/1YW', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '2040', 'Supplier Price (Tax Excl.)': '499.0', 'brand': 'HP', 'Short Description': 'HP260 G4 DM I3-10110U/8GB/256GB SSD/WIFI/Stand/W10p64/1yw', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">HP260 G4 DM                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">23G84EAABT                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10110U Processor (4M Cache, up to 4.10 GHz)                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Windows 10  PRO                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O</strong><br role="presentation">Headphone/microphone combo<br role="presentation">SuperSpeed USB Type-C® 10Gbps signaling rate<br role="presentation">SuperSpeed USB Type-A 5Gbpssignaling rate<br role="presentation">USB Type-A 480Mbps signaling rate</p><p data-andiallelmwithtext="16"><br role="presentation"><strong data-andiallelmwithtext="16">Rear I/O</strong><br role="presentation">RJ-45<br role="presentation">VGA<br role="presentation">serial<br role="presentation">HDMI 1.4<br  ...
# 2021-02-05 11:30:09.188071 (delta = 0:00:00.001997) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data {'category': '1,2,91,89,231,235', 'Supplier Reference': '23G84EA#ABT', 'Reference': 'CDT-23G84EA#ABT', 'manufacrurer reference': '23G84EA#ABT', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'HP260 G4 DM I3-10110U/8GB/256GB SSD/WIFI/STAND/W10P64/1YW', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '2040', 'Supplier Price (Tax Excl.)': '499.0', 'brand': 'HP', 'Short Description': 'HP260 G4 DM I3-10110U/8GB/256GB SSD/WIFI/Stand/W10p64/1yw', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">HP260 G4 DM                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">23G84EAABT                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10110U Processor (4M Cache, up to 4.10 GHz)                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Windows 10  PRO                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O</strong><br role="presentation">Headphone/microphone combo<br role="presentation">SuperSpeed USB Type-C® 10Gbps signaling rate<br role="presentation">SuperSpeed USB Type-A 5Gbpssignaling rate<br role="presentation">USB Type-A 480Mbps signaling rate</p><p data-andiallelmwithtext="16"><br role="presentation"><strong data-andiallelmwithtext="16">Rear I/O</strong><br role="presentation">RJ-45<br role="presentation">VGA<br role="presentation">serial<br role="presentation">HDMI 1.4<b ...
# 2021-02-05 11:30:09.190068 (delta = 0:00:00.001997) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2021-02-05 11:30:12.208496 (delta = 0:00:03.018428) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/asusd300ta-mt-i3-10100-8gb-ddr4-256gb-m2-ssdfd-3yr-os
#             Title : C-Data. ASUS/D300TA-MT /i3-10100 /8GB DDR4 /256GB M.2 SSD/FD /3yr OS
# 2021-02-05 11:30:12.760788 (delta = 0:00:00.552292) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2021-02-05 11:30:12.762779 (delta = 0:00:00.001991) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data False
# 2021-02-05 11:30:12.763778 (delta = 0:00:00.000999) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2021-02-05 11:30:14.794770 (delta = 0:00:02.030992) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/hp290-g4-mt-i3-101008gb256gb-mvmewififree-dos1yw
#             Title : C-Data. HP290 G4 MT i3-10100/8GB/256GB MVME/NO WIFI/FREE DOS/1YW
# 2021-02-05 11:30:14.823695 (delta = 0:00:00.028925) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2021-02-05 11:30:14.824690 (delta = 0:00:00.000995) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data False
# 2021-02-05 11:30:14.825689 (delta = 0:00:00.000999) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2021-02-05 11:30:27.484039 (delta = 0:00:12.658350) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/dell-optiplex-3080-mff-i3-10100t8gb256ssdintel-hddoswifi3y-os
#             Title : C-Data. Dell OPTIPLEX 3080 MFF I3-10100T/8GB/256SSD/INTEL HD/DOS/WIFI/3Y-OS
# 2021-02-05 11:30:27.623780 (delta = 0:00:00.139741) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2021-02-05 11:30:27.625776 (delta = 0:00:00.001996) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data False
# 2021-02-05 11:30:27.626772 (delta = 0:00:00.000996) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2021-02-05 11:30:29.322867 (delta = 0:00:01.696095) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/dell-vostro-pc-3888-i3-103008gbrw256gb-ssdintel-uhd-630doswifi3y-os
#             Title : C-Data. Dell VOSTRO PC 3888 I3-10300/8GB/RW/256GB SSD/Intel UHD 630/DOS/WIFI/3Y-OS
# 2021-02-05 11:30:29.486429 (delta = 0:00:00.163562) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku V3888-3003 ---
# 2021-02-05 11:30:29.523332 (delta = 0:00:00.036903) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $488.00
#
# 2021-02-05 11:30:29.585228 (delta = 0:00:00.061896) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена до округления 1998.36
# 2021-02-05 11:30:29.587219 (delta = 0:00:00.001991) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена после округления 2000
# 2021-02-05 11:30:30.595716 (delta = 0:00:01.008497) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = V3888-3003
# 2021-02-05 11:30:30.625637 (delta = 0:00:00.029921) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,91,89,231,235', 'Supplier Reference': 'V3888-3003', 'Reference': 'CDT-V3888-3003', 'manufacrurer reference': 'V3888-3003', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'DELL VOSTRO PC 3888 I3-10300/8GB/RW/256GB SSD/INTEL UHD 630/DOS/WIFI/3Y-OS', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '2000', 'Supplier Price (Tax Excl.)': '488.0', 'brand': 'HP', 'Short Description': 'Dell VOSTRO PC 3888 I3-10300/8GB/RW/256GB SSD/Intel UHD 630/DOS/WIFI/3Y-OS', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Dell VOSTRO PC 3888                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">V3888-3003                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10300 Processor 8M Cache, up to 4.40 GHz                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB DDR4                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB M.2 PCIe NVMe SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Free Dos                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics 630                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                קישוריות                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">802.11ac 1x1 WiFi and Bluetooth                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O</strong><br role="presentation">2xUSB 2.0 Gen 1<br role="presentati ...
# 2021-02-05 11:30:30.626635 (delta = 0:00:00.000998) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data {'category': '1,2,91,89,231,235', 'Supplier Reference': 'V3888-3003', 'Reference': 'CDT-V3888-3003', 'manufacrurer reference': 'V3888-3003', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'DELL VOSTRO PC 3888 I3-10300/8GB/RW/256GB SSD/INTEL UHD 630/DOS/WIFI/3Y-OS', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '2000', 'Supplier Price (Tax Excl.)': '488.0', 'brand': 'HP', 'Short Description': 'Dell VOSTRO PC 3888 I3-10300/8GB/RW/256GB SSD/Intel UHD 630/DOS/WIFI/3Y-OS', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Dell VOSTRO PC 3888                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">V3888-3003                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Core™ i3-10300 Processor 8M Cache, up to 4.40 GHz                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">8GB DDR4                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">256GB M.2 PCIe NVMe SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Free Dos                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® UHD Graphics 630                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                קישוריות                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">802.11ac 1x1 WiFi and Bluetooth                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יציאות וחיבורים                            </td>                            <td class="spec-value"><p data-andiallelmwithtext="16"><strong data-andiallelmwithtext="16">Front I/O</strong><br role="presentation">2xUSB 2.0 Gen 1<br role="presenta ...
# 2021-02-05 11:30:30.627633 (delta = 0:00:00.000998) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2021-02-05 11:30:32.390200 (delta = 0:00:01.762567) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
# ...
# 2021-02-05 11:53:21.660555 (delta = 0:00:00.000994) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data {'category': '1,2,3,48,10,5,434,626,49', 'Supplier Reference': 'GX550LXS-HC185T', 'Reference': 'CDT-GX550LXS-HC185T', 'manufacrurer reference': 'GX550LXS-HC185T', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'GX550LXS - 15.6 4K/  I7-10875H/ 32GB DDR4/ 1T M.2 SSD /RTX2080S-8GB/GRAY/ WIN10 HOME/ 1 YR', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '15460', 'Supplier Price (Tax Excl.)': '3775.0', 'brand': 'ASUS', 'Short Description': 'GX550LXS - 15.6 4K/  i7-10875H/ 32GB DDR4/ 1T M.2 SSD /RTX2080S-8GB/Gray/ Win10 Home/ 1 yr', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">ROG Zephyrus Duo 15                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">GX550LXS-HC185T                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                גודל תצוגה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">15.6                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                רזולוציית תצוגה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">(4K UHD (3840 x 2160                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">(Intel® Core™ i7-10875H Processor 2.3 GHz (16M Cache, up to 5.1 GHz                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">(32GB (16GB DDR4 on board + 16GB DDR4 SO-DIMM                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">1TB M.2 NVMe™ PCIe® 3.0 Performance SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Windows 10 HOME                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">NVIDIA®Ge ...
# 2021-02-05 11:53:21.662550 (delta = 0:00:00.001995) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2021-02-05 11:53:23.677424 (delta = 0:00:02.014874) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/asusp1440-i5_1021014-fhdram-8gb256ssd-black-win10-home-1yr-os
#             Title : C-Data. ASUS/P1440- I5_10210/14" FHD/RAM 8GB/256SSD/ BLACK/ WIN10 HOME/ 1YR OS
# 2021-02-05 11:53:24.002553 (delta = 0:00:00.325129) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2021-02-05 11:53:24.004548 (delta = 0:00:00.001995) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data False
# 2021-02-05 11:53:24.006542 (delta = 0:00:00.001994) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2021-02-05 11:53:26.461134 (delta = 0:00:02.454592) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/asusb9400cea-i7-1165g7-14-fhd-32gb-ddr42tb-ssd-2tb-ssd3-year-oswin-10-problack
#             Title : C-Data. ASUS/B9400CEA-i7-1165G7 /14” FHD /32GB DDR4/2TB SSD+ 2TB SSD/3 year OS/WIN 10 PRO/BLACK
# 2021-02-05 11:53:26.643642 (delta = 0:00:00.182508) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku B9400CEA-KC0285R ---
# 2021-02-05 11:53:26.671567 (delta = 0:00:00.027925) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $2,711.00
#
# 2021-02-05 11:53:26.733400 (delta = 0:00:00.061833) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена до округления 11101.545
# 2021-02-05 11:53:26.734400 (delta = 0:00:00.001000) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   цена после округления 11100
# 2021-02-05 11:53:27.836654 (delta = 0:00:01.102254) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = B9400CEA-KC0285R
# 2021-02-05 11:53:27.873556 (delta = 0:00:00.036902) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,3,48,10,5,434,626,49', 'Supplier Reference': 'B9400CEA-KC0285R', 'Reference': 'CDT-B9400CEA-KC0285R', 'manufacrurer reference': 'B9400CEA-KC0285R', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'ASUS/B9400CEA-I7-1165G7 /14” FHD /32GB DDR4/2TB SSD+ 2TB SSD/3 YEAR OS/WIN 10 PRO/BLACK', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '11100', 'Supplier Price (Tax Excl.)': '2711.0', 'brand': 'ASUS', 'Short Description': 'ASUS/B9400CEA-i7-1165G7 /14” FHD /32GB DDR4/2TB SSD+ 2TB SSD/3 year OS/WIN 10 PRO/BLACK', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">ASUS ExpertBook B9                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">B9400CEA-KC0285R                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                גודל תצוגה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">14"                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                רזולוציית תצוגה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">FHD 1920x1080                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">(Intel® Core™ i7-1165G7 Processor 2.8 GHz (12M Cache, up to 4.7 GHz                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">32GB LPDDR4X                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">2TB + 2TB M.2 NVMe™ PCIe® 3.0 Performance RAID0 SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Windows 10  PRO                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Iris Xe Graphics                     ...
# 2021-02-05 11:53:27.874555 (delta = 0:00:00.000999) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data {'category': '1,2,3,48,10,5,434,626,49', 'Supplier Reference': 'B9400CEA-KC0285R', 'Reference': 'CDT-B9400CEA-KC0285R', 'manufacrurer reference': 'B9400CEA-KC0285R', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'ASUS/B9400CEA-I7-1165G7 /14” FHD /32GB DDR4/2TB SSD+ 2TB SSD/3 YEAR OS/WIN 10 PRO/BLACK', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '11100', 'Supplier Price (Tax Excl.)': '2711.0', 'brand': 'ASUS', 'Short Description': 'ASUS/B9400CEA-i7-1165G7 /14” FHD /32GB DDR4/2TB SSD+ 2TB SSD/3 year OS/WIN 10 PRO/BLACK', 'Description': '<p font-size="x-small" color="" >upd: 05/02</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                דגם                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">ASUS ExpertBook B9                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מק"ט                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">B9400CEA-KC0285R                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                גודל תצוגה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">14"                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                רזולוציית תצוגה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">FHD 1920x1080                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">(Intel® Core™ i7-1165G7 Processor 2.8 GHz (12M Cache, up to 4.7 GHz                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                זיכרון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">32GB LPDDR4X                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                אחסון                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">2TB + 2TB M.2 NVMe™ PCIe® 3.0 Performance RAID0 SSD                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                מערכת הפעלה                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Windows 10  PRO                            </td>                        </tr>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                כרטיס גרפי                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">Intel® Iris Xe Graphics                   ...
# 2021-02-05 11:53:27.876548 (delta = 0:00:00.001993) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   ############ ТОВАР добавлен
