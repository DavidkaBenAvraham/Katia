# %%
import main
main.run()
# Out:
# 2021-05-04 18:25:55.196258 (delta = 0:00:00.009003) 	 : 	 __init__->__init__->write:
#         LOG STR:   supplier_settings = <module 'suppliers.cdata' from 'C:\\Users\\onela\\OneDrive\\REPOS\\Aluf\\Aluf\\suppliers\\cdata\\__init__.py'>  supplier_class:
# ...
# 2021-05-04 18:25:55.197258 (delta = 0:00:00.001000) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс cdata supplier_class:
# ...
# 2021-05-04 18:26:01.762081 (delta = 0:00:06.564823) 	 : 	 run->get_url->write:
#         LOG STR:   Current URL: https://c-data.co.il/ supplier_class:
# ...
# 2021-05-04 18:26:03.358378 (delta = 0:00:00.003999) 	 : 	 __init__->__init__->write:
#         LOG STR:   supplier_settings = <module 'suppliers.morlevi' from 'C:\\Users\\onela\\OneDrive\\REPOS\\Aluf\\Aluf\\suppliers\\morlevi\\__init__.py'>  supplier_class:
# ...
# 2021-05-04 18:26:03.359380 (delta = 0:00:00.001002) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс morlevi supplier_class:
# ...
