# %%
import main

suppliers_names = ['cdata','mor','grand','vdg']
one_supplier = ['vdg']
scenario = [    "visualdg_categories_minipc_asus.json",
    "visualdg_categories_mb_asus.json",
    "visualdg_categories_video_asus.json"]

scenario =["visualdg_categories_cases_asus.json" , "visualdg_categories_monitors_asus.json"]

for supplier_name in one_supplier:
    supplier = main.run_supplier(supplier_name)
    if supplier != False: main.run_scenario(supplier ,scenario )
# Out:
# 2020-10-15 18:20:24.230900 (delta = 0:00:00.001000) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс Driver()
# 2020-10-15 18:20:30.351287 (delta = 0:00:06.120387) 	 : 	 run_supplier->__init__->write:
#         LOG STR:  запустился класс vdg
# 2020-10-15 18:20:34.473223 (delta = 0:00:04.121936) 	 : 	 run->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/
#             Title : Visual D.G. | ויזואל ד.ג
# 2020-10-15 18:20:35.501453 (delta = 0:00:01.028230) 	 : 	 logged_in->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/customer_login
#             Title : כניסת לקוחות
# 2020-10-15 18:20:35.860537 (delta = 0:00:00.359084) 	 : 	 run->logged_in->write:
#         LOG STR:  VDG logged in
# 2020-10-15 18:20:36.813751 (delta = 0:00:00.953214) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
# ...
