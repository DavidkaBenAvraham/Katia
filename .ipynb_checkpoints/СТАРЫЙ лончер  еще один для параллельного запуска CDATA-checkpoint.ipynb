# %%
import main

suppliers_names = ['cdata','mor','grand','vdg']
one_supplier = ['cdata']

scenario = ["cdata_categories_aio_asus.json",
            "cdata_categories_aio_dell.json",
            "cdata_categories_aio_hp.json"]

scenario = ["cdata_categories_video.json","cdata_categories_webcams.json"]
scenario = [ "cdata_categories_laptops_dell.json",
    "cdata_categories_laptops_hp.json",
    "cdata_categories_gaming_laptops_asus.json",
    "cdata_categories_gaming_laptops_dell.json",
    "cdata_categories_gaming_laptops_hp.json",
    "cdata_categories_monitors_apple.json",
    "cdata_categories_monitors_dell.json",
    "cdata_categories_monitors_hp.json",
    "cdata_categories_printers.json",
    "cdata_categories_workstatios.json",
    "cdata_categories_webcams.json",
    "cdata_categories_ups.json",
    "cdata_categories_video.json"]

scenario = ["cdata_categories_laptops_asus.json"]

for supplier_name in one_supplier:
    supplier = main.run_supplier(supplier_name)
    if supplier != False: main.run_scenario(supplier, scenario)
# Out:
# 2020-11-05 22:13:19.509737 (delta = 0:00:00.002004) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс Driver()
# 2020-11-05 22:13:30.350908 (delta = 0:00:10.841171) 	 : 	 run_supplier->__init__->write:
#         LOG STR:  запустился класс Cdata
# 2020-11-05 22:13:36.435115 (delta = 0:00:06.084207) 	 : 	 run->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.c-data.co.il/
#             Title : C-Data
# 2020-11-05 22:13:38.673361 (delta = 0:00:02.238246) 	 : 	 logged_in->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/Login
#             Title : C-Data. כניסה
# 2020-11-05 22:13:43.197438 (delta = 0:00:04.524077) 	 : 	 run->logged_in->write:
#         LOG STR:  C-data logged in
# 2020-11-05 22:13:46.792768 (delta = 0:00:03.595330) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-2#/specFilters=235m!#-!5767
#             Title : C-Data. NVIDIA
# 2020-11-05 22:13:48.527108 (delta = 0:00:01.734340) 	 : 	 sozdaj_ssylki_na_tovary->sozdaj_spisok_ssylok_na_stranicy_tovarov_so_stranicy_kategorii->write:
#         LOG STR:   Собрал со страницы категории ссылки на товары:
#     ['https://reseller.c-data.co.il/nvidia-quadro-p6000-24gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p6000-24gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p6000-24gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-k620-2gb-ddr3-pcie-20-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-k620-2gb-ddr3-pcie-20-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-k620-2gb-ddr3-pcie-20-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p1000-4gb-gddr5-pcie-30-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p1000-4gb-gddr5-pcie-30-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p1000-4gb-gddr5-pcie-30-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p400', 'https://reseller.c-data.co.il/nvidia-quadro-p400', 'https://reseller.c-data.co.il/nvidia-quadro-p400', 'https://reseller.c-data.co.il/nvidia-quadro-p2000-5gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p2000-5gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p2000-5gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p4000-8gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p4000-8gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p4000-8gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p5000-16gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p5000-16gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p5000-16gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p620-', 'https://reseller.c-data.co.il/nvidia-quadro-p620-', 'https://reseller.c-data.co.il/nvidia-quadro-p620-', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-4000-8gb-gddr6', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-4000-8gb-gddr6', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-4000-8gb-gddr6', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-5000-16-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-5000-16-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-5000-16-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-6000-24-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-6000-24-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-6000-24-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-8000-48-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-8000-48-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-8000-48-gb-gddr6-with-ecc']
# 2020-11-05 22:14:04.069021 (delta = 0:00:15.541913) 	 : 	 click_to_next_page->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', 'li.next-page a')
# 2020-11-05 22:14:04.076001 (delta = 0:00:00.006980) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   собранны ссылки на товары : ['https://reseller.c-data.co.il/nvidia-quadro-p5000-16gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p400', 'https://reseller.c-data.co.il/nvidia-quadro-p2000-5gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-5000-16-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-p4000-8gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-8000-48-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-4000-8gb-gddr6', 'https://reseller.c-data.co.il/nvidia-quadro-p6000-24gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-p1000-4gb-gddr5-pcie-30-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-k620-2gb-ddr3-pcie-20-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/nvidia-quadro-rtx-6000-24-gb-gddr6-with-ecc', 'https://reseller.c-data.co.il/nvidia-quadro-p620-']
# 2020-11-05 22:14:06.465167 (delta = 0:00:02.389166) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-p5000-16gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. NVIDIA Quadro P6000 24GB GDDR5 PCIE 3.0 X16
# 2020-11-05 22:14:06.533983 (delta = 0:00:00.068816) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:14:06.535977 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:14:06.537971 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:14:08.845833 (delta = 0:00:02.307862) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-p400
#             Title : C-Data. NVIDIA Quadro P400
# 2020-11-05 22:14:09.209099 (delta = 0:00:00.363266) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:14:09.211064 (delta = 0:00:00.001965) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:14:09.213058 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:14:12.635161 (delta = 0:00:03.422103) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-p2000-5gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. NVIDIA Quadro P4000 8GB GDDR5 PCIE 3.0 X16
# 2020-11-05 22:14:12.887518 (delta = 0:00:00.252357) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:14:12.889511 (delta = 0:00:00.001993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:14:12.891508 (delta = 0:00:00.001997) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:14:14.808896 (delta = 0:00:01.917388) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-rtx-5000-16-gb-gddr6-with-ecc
#             Title : C-Data. NVIDIA Quadro RTX 5000 16 GB GDDR6 with ECC
# 2020-11-05 22:14:30.446909 (delta = 0:00:15.638013) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', '.value.stock_staus')
# 2020-11-05 22:14:30.480952 (delta = 0:00:00.034043) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku VCQRTX5000-PB ---
# 2020-11-05 22:14:30.507882 (delta = 0:00:00.026930) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#
#
# 2020-11-05 22:14:30.576731 (delta = 0:00:00.068849) 	 : 	 get_all->round_price->write:
#         LOG STR:   Проблема с получением цены. Она выглядит так: [] !!! Будет  ХУЙ !
# 2020-11-05 22:14:30.578690 (delta = 0:00:00.001959) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 0.0
# 2020-11-05 22:14:30.580686 (delta = 0:00:00.001996) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 10
# 2020-11-05 22:14:46.119637 (delta = 0:00:15.538951) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', ".data-table[role='presentation']")
# 2020-11-05 22:14:46.122539 (delta = 0:00:00.002902) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = VCQRTX5000-PB
# 2020-11-05 22:14:46.161434 (delta = 0:00:00.038895) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX5000-PB', 'Reference': 'CDT-VCQRTX5000-PB', 'manufacrurer reference': 'VCQRTX5000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 5000     16 GB GDDR6 WITH ECC', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '10', 'Supplier Price (Tax Excl.)': '0.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 5000     16 GB GDDR6 with ECC', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004466_nvidia-quadro-rtx-5000-16-gb-gddr6-with-ecc_600.png', 'Imgs alt. text': 'VCQRTX5000-PB NVIDIA QUADRO RTX 5000     16 GB GDDR6 WITH ECC', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX5000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:14:46.163431 (delta = 0:00:00.001997) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX5000-PB', 'Reference': 'CDT-VCQRTX5000-PB', 'manufacrurer reference': 'VCQRTX5000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 5000     16 GB GDDR6 WITH ECC', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '10', 'Supplier Price (Tax Excl.)': '0.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 5000     16 GB GDDR6 with ECC', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004466_nvidia-quadro-rtx-5000-16-gb-gddr6-with-ecc_600.png', 'Imgs alt. text': 'VCQRTX5000-PB NVIDIA QUADRO RTX 5000     16 GB GDDR6 WITH ECC', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX5000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:14:46.165426 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:14:48.527130 (delta = 0:00:02.361704) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-p4000-8gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. NVIDIA Quadro P5000 16GB GDDR5 PCIE 3.0 X16
# 2020-11-05 22:14:48.577959 (delta = 0:00:00.050829) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:14:48.579953 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:14:48.582946 (delta = 0:00:00.002993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:14:51.110922 (delta = 0:00:02.527976) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-rtx-8000-48-gb-gddr6-with-ecc
#             Title : C-Data. NVIDIA Quadro RTX 8000 48 GB GDDR6 with ECC
# 2020-11-05 22:15:06.734916 (delta = 0:00:15.623994) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', '.value.stock_staus')
# 2020-11-05 22:15:06.772815 (delta = 0:00:00.037899) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku VCQRTX8000-PB ---
# 2020-11-05 22:15:06.804727 (delta = 0:00:00.031912) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#
#
# 2020-11-05 22:15:06.884514 (delta = 0:00:00.079787) 	 : 	 get_all->round_price->write:
#         LOG STR:   Проблема с получением цены. Она выглядит так: [] !!! Будет  ХУЙ !
# 2020-11-05 22:15:06.886510 (delta = 0:00:00.001996) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 0.0
# 2020-11-05 22:15:06.888506 (delta = 0:00:00.001996) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 10
# 2020-11-05 22:15:22.428829 (delta = 0:00:15.540323) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', ".data-table[role='presentation']")
# 2020-11-05 22:15:22.431822 (delta = 0:00:00.002993) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = VCQRTX8000-PB
# 2020-11-05 22:15:22.475703 (delta = 0:00:00.043881) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX8000-PB', 'Reference': 'CDT-VCQRTX8000-PB', 'manufacrurer reference': 'VCQRTX8000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 8000  48 GB GDDR6 WITH ECC', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '10', 'Supplier Price (Tax Excl.)': '0.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 8000  48 GB GDDR6 with ECC', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004474_nvidia-quadro-rtx-8000-48-gb-gddr6-with-ecc_600.png', 'Imgs alt. text': 'VCQRTX8000-PB NVIDIA QUADRO RTX 8000  48 GB GDDR6 WITH ECC', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX8000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:15:22.477699 (delta = 0:00:00.001996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX8000-PB', 'Reference': 'CDT-VCQRTX8000-PB', 'manufacrurer reference': 'VCQRTX8000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 8000  48 GB GDDR6 WITH ECC', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '10', 'Supplier Price (Tax Excl.)': '0.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 8000  48 GB GDDR6 with ECC', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004474_nvidia-quadro-rtx-8000-48-gb-gddr6-with-ecc_600.png', 'Imgs alt. text': 'VCQRTX8000-PB NVIDIA QUADRO RTX 8000  48 GB GDDR6 WITH ECC', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX8000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:15:22.479696 (delta = 0:00:00.001997) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:15:26.627214 (delta = 0:00:04.147518) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-rtx-4000-8gb-gddr6
#             Title : C-Data. NVIDIA Quadro RTX 4000 8GB GDDR6
# 2020-11-05 22:15:26.812709 (delta = 0:00:00.185495) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku VCQRTX4000-PB ---
# 2020-11-05 22:15:26.840635 (delta = 0:00:00.027926) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $952.00
#
# 2020-11-05 22:15:26.914438 (delta = 0:00:00.073803) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 3898.4399999999996
# 2020-11-05 22:15:26.916434 (delta = 0:00:00.001996) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 3900
# 2020-11-05 22:15:42.468630 (delta = 0:00:15.552196) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', ".data-table[role='presentation']")
# 2020-11-05 22:15:42.471622 (delta = 0:00:00.002992) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = VCQRTX4000-PB
# 2020-11-05 22:15:42.544427 (delta = 0:00:00.072805) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX4000-PB', 'Reference': 'CDT-VCQRTX4000-PB', 'manufacrurer reference': 'VCQRTX4000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 4000  8GB GDDR6', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '3900', 'Supplier Price (Tax Excl.)': '952.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 4000  8GB GDDR6', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004462_nvidia-quadro-rtx-4000-8gb-gddr6_600.png', 'Imgs alt. text': 'VCQRTX4000-PB NVIDIA QUADRO RTX 4000  8GB GDDR6', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX4000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:15:42.546421 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX4000-PB', 'Reference': 'CDT-VCQRTX4000-PB', 'manufacrurer reference': 'VCQRTX4000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 4000  8GB GDDR6', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '3900', 'Supplier Price (Tax Excl.)': '952.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 4000  8GB GDDR6', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004462_nvidia-quadro-rtx-4000-8gb-gddr6_600.png', 'Imgs alt. text': 'VCQRTX4000-PB NVIDIA QUADRO RTX 4000  8GB GDDR6', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX4000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:15:42.548417 (delta = 0:00:00.001996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:15:43.899428 (delta = 0:00:01.351011) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-p6000-24gb-gddr5-pcie-30-x16-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. NVIDIA Quadro GP100 16GB GDDR5 PCIE 3.0 X16
# 2020-11-05 22:15:44.055010 (delta = 0:00:00.155582) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:15:44.058003 (delta = 0:00:00.002993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:15:44.059997 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:15:46.275577 (delta = 0:00:02.215580) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-p1000-4gb-gddr5-pcie-30-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. NVIDIA Quadro P2000 5GB GDDR5 PCIE 3.0 X16
# 2020-11-05 22:15:46.507955 (delta = 0:00:00.232378) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:15:46.510949 (delta = 0:00:00.002994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:15:46.513940 (delta = 0:00:00.002991) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:15:48.859740 (delta = 0:00:02.345800) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-k620-2gb-ddr3-pcie-20-x16-atx-bracket-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. NVIDIA Quadro P1000 4GB GDDR5 PCIE 3.0 X16
# 2020-11-05 22:15:49.138992 (delta = 0:00:00.279252) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku VCQP1000V2-PB ---
# 2020-11-05 22:15:49.184868 (delta = 0:00:00.045876) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $339.00
#
# 2020-11-05 22:15:49.292580 (delta = 0:00:00.107712) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 1388.205
# 2020-11-05 22:15:49.294578 (delta = 0:00:00.001998) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 1390
# 2020-11-05 22:16:04.838708 (delta = 0:00:15.544130) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', ".data-table[role='presentation']")
# 2020-11-05 22:16:04.846631 (delta = 0:00:00.007923) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = VCQP1000V2-PB
# 2020-11-05 22:16:04.894537 (delta = 0:00:00.047906) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,111', 'Supplier Reference': 'VCQP1000V2-PB', 'Reference': 'CDT-VCQP1000V2-PB', 'manufacrurer reference': 'VCQP1000V2-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO P1000 4GB GDDR5 PCIE 3.0 X16', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '1390', 'Supplier Price (Tax Excl.)': '339.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro P1000 4GB GDDR5 PCIE 3.0 X16', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0001919_nvidia-quadro-p1000-4gb-gddr5-pcie-30-x16_600.png', 'Imgs alt. text': 'VCQP1000V2-PB NVIDIA QUADRO P1000 4GB GDDR5 PCIE 3.0 X16', 'delete old images': '1', 'meta_words': 'QUATRO VCQP1000V2-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:16:04.896499 (delta = 0:00:00.001962) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,111', 'Supplier Reference': 'VCQP1000V2-PB', 'Reference': 'CDT-VCQP1000V2-PB', 'manufacrurer reference': 'VCQP1000V2-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO P1000 4GB GDDR5 PCIE 3.0 X16', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '1390', 'Supplier Price (Tax Excl.)': '339.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro P1000 4GB GDDR5 PCIE 3.0 X16', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0001919_nvidia-quadro-p1000-4gb-gddr5-pcie-30-x16_600.png', 'Imgs alt. text': 'VCQP1000V2-PB NVIDIA QUADRO P1000 4GB GDDR5 PCIE 3.0 X16', 'delete old images': '1', 'meta_words': 'QUATRO VCQP1000V2-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:16:04.898494 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:16:07.002552 (delta = 0:00:02.104058) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-rtx-6000-24-gb-gddr6-with-ecc
#             Title : C-Data. NVIDIA Quadro RTX 6000 24 GB GDDR6 with ECC
# 2020-11-05 22:16:22.629102 (delta = 0:00:15.626550) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', '.value.stock_staus')
# 2020-11-05 22:16:22.661014 (delta = 0:00:00.031912) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku VCQRTX6000-PB ---
# 2020-11-05 22:16:22.691933 (delta = 0:00:00.030919) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#
#
# 2020-11-05 22:16:22.773715 (delta = 0:00:00.081782) 	 : 	 get_all->round_price->write:
#         LOG STR:   Проблема с получением цены. Она выглядит так: [] !!! Будет  ХУЙ !
# 2020-11-05 22:16:22.775709 (delta = 0:00:00.001994) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 0.0
# 2020-11-05 22:16:22.777704 (delta = 0:00:00.001995) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 10
# 2020-11-05 22:16:38.318612 (delta = 0:00:15.540908) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', ".data-table[role='presentation']")
# 2020-11-05 22:16:38.320369 (delta = 0:00:00.001757) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = VCQRTX6000-PB
# 2020-11-05 22:16:38.357814 (delta = 0:00:00.037445) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX6000-PB', 'Reference': 'CDT-VCQRTX6000-PB', 'manufacrurer reference': 'VCQRTX6000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 6000 24 GB GDDR6 WITH ECC', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '10', 'Supplier Price (Tax Excl.)': '0.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 6000 24 GB GDDR6 with ECC', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004470_nvidia-quadro-rtx-6000-24-gb-gddr6-with-ecc_600.png', 'Imgs alt. text': 'VCQRTX6000-PB NVIDIA QUADRO RTX 6000 24 GB GDDR6 WITH ECC', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX6000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:16:38.359812 (delta = 0:00:00.001998) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,111', 'Supplier Reference': 'VCQRTX6000-PB', 'Reference': 'CDT-VCQRTX6000-PB', 'manufacrurer reference': 'VCQRTX6000-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO RTX 6000 24 GB GDDR6 WITH ECC', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '10', 'Supplier Price (Tax Excl.)': '0.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro RTX 6000 24 GB GDDR6 with ECC', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004470_nvidia-quadro-rtx-6000-24-gb-gddr6-with-ecc_600.png', 'Imgs alt. text': 'VCQRTX6000-PB NVIDIA QUADRO RTX 6000 24 GB GDDR6 WITH ECC', 'delete old images': '1', 'meta_words': 'QUATRO VCQRTX6000-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:16:38.360811 (delta = 0:00:00.000999) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:16:40.627322 (delta = 0:00:02.266511) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-quadro-p620-
#             Title : C-Data. NVIDIA Quadro P620
# 2020-11-05 22:16:40.809833 (delta = 0:00:00.182511) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku VCQP620V2-PB ---
# 2020-11-05 22:16:40.831775 (delta = 0:00:00.021942) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $180.00
#
# 2020-11-05 22:16:40.894615 (delta = 0:00:00.062840) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 737.0999999999999
# 2020-11-05 22:16:40.896602 (delta = 0:00:00.001987) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 740
# 2020-11-05 22:16:56.446446 (delta = 0:00:15.549844) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', ".data-table[role='presentation']")
# 2020-11-05 22:16:56.452359 (delta = 0:00:00.005913) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = VCQP620V2-PB
# 2020-11-05 22:16:56.493246 (delta = 0:00:00.040887) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,111', 'Supplier Reference': 'VCQP620V2-PB', 'Reference': 'CDT-VCQP620V2-PB', 'manufacrurer reference': 'VCQP620V2-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO P620', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '740', 'Supplier Price (Tax Excl.)': '180.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro P620', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004477_nvidia-quadro-p620_600.png', 'Imgs alt. text': 'VCQP620V2-PB NVIDIA QUADRO P620', 'delete old images': '1', 'meta_words': 'QUATRO VCQP620V2-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:16:56.495243 (delta = 0:00:00.001997) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,111', 'Supplier Reference': 'VCQP620V2-PB', 'Reference': 'CDT-VCQP620V2-PB', 'manufacrurer reference': 'VCQP620V2-PB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'NVIDIA QUADRO P620', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '740', 'Supplier Price (Tax Excl.)': '180.0', 'brand': 'QUATRO', 'Short Description': 'NVIDIA Quadro P620', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>None', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0004477_nvidia-quadro-p620_600.png', 'Imgs alt. text': 'VCQP620V2-PB NVIDIA QUADRO P620', 'delete old images': '1', 'meta_words': 'QUATRO VCQP620V2-PB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:16:56.497238 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:16:56.500229 (delta = 0:00:00.002991) 	 : 	 get_all->flush_p->write:
#         LOG STR:   -----------------
#             скидываю товары в файл CDT-Quatro.csv
#     -------------
# 2020-11-05 22:16:56.515189 (delta = 0:00:00.014960) 	 : 	 flush_p->export->write:
#         LOG STR:   Данные экспортированы в файл
#        ..\export\CDT-Quatro.csv
# 2020-11-05 22:16:56.516187 (delta = 0:00:00.000998) 	 : 	 get_all->flush_p->write:
#         LOG STR:  OK!
# 2020-11-05 22:16:58.560071 (delta = 0:00:02.043884) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/nvidia-2#/specFilters=235m!#-!6174
#             Title : C-Data. NVIDIA
# 2020-11-05 22:16:59.973851 (delta = 0:00:01.413780) 	 : 	 sozdaj_ssylki_na_tovary->sozdaj_spisok_ssylok_na_stranicy_tovarov_so_stranicy_kategorii->write:
#         LOG STR:   Собрал со страницы категории ссылки на товары:
#     ['https://reseller.c-data.co.il/-gtx-1650-super-4gb', 'https://reseller.c-data.co.il/-gtx-1650-super-4gb', 'https://reseller.c-data.co.il/geforce-rtx-3070-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/geforce-rtx-3070-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/geforce-rtx-3080-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/geforce-rtx-3080-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/geforce-rtx-3090-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/geforce-rtx-3090-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/geforce-gtx-1650-4gb-xlr8-gaming', 'https://reseller.c-data.co.il/geforce-gtx-1650-4gb-xlr8-gaming', 'https://reseller.c-data.co.il/gtx-1660-xlr8-gaming-overclocked-single-fan-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/gtx-1660-xlr8-gaming-overclocked-single-fan-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/gtx-1660-super-single-fan-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/gtx-1660-super-single-fan-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/gtx-1660-ti-xlr8-gaming-overclocked-single-fan', 'https://reseller.c-data.co.il/gtx-1660-ti-xlr8-gaming-overclocked-single-fan', 'https://reseller.c-data.co.il/gtx-1660-xlr8-gaming-overclocked-single-fan', 'https://reseller.c-data.co.il/gtx-1660-xlr8-gaming-overclocked-single-fan', 'https://reseller.c-data.co.il/pny-geforce-gtx-1650-4gb-dual-fan-4gb-gddr6-128-bit', 'https://reseller.c-data.co.il/pny-geforce-gtx-1650-4gb-dual-fan-4gb-gddr6-128-bit', 'https://reseller.c-data.co.il/rtx-2080-ti-11gb-xlr8-gaming-overclocked-edition', 'https://reseller.c-data.co.il/rtx-2080-ti-11gb-xlr8-gaming-overclocked-edition', 'https://reseller.c-data.co.il/rtx-2060-super-twin-fan8gb-gddr6-256-bit', 'https://reseller.c-data.co.il/rtx-2060-super-twin-fan8gb-gddr6-256-bit', 'https://reseller.c-data.co.il/rtx-2070-super-xlr8-oc-triple-fan8gb-gddr6-256-bitpci-e-30-x16', 'https://reseller.c-data.co.il/rtx-2070-super-xlr8-oc-triple-fan8gb-gddr6-256-bitpci-e-30-x16', 'https://reseller.c-data.co.il/rtx-2080-super-blower8gb-gddr6-256-bit', 'https://reseller.c-data.co.il/rtx-2080-super-blower8gb-gddr6-256-bit']
# 2020-11-05 22:17:15.494493 (delta = 0:00:15.520642) 	 : 	 click_to_next_page->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', 'li.next-page a')
# 2020-11-05 22:17:15.503162 (delta = 0:00:00.008669) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   собранны ссылки на товары : ['https://reseller.c-data.co.il/gtx-1660-xlr8-gaming-overclocked-single-fan-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/geforce-rtx-3080-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/gtx-1660-ti-xlr8-gaming-overclocked-single-fan', 'https://reseller.c-data.co.il/pny-geforce-gtx-1650-4gb-dual-fan-4gb-gddr6-128-bit', 'https://reseller.c-data.co.il/-gtx-1650-super-4gb', 'https://reseller.c-data.co.il/rtx-2070-super-xlr8-oc-triple-fan8gb-gddr6-256-bitpci-e-30-x16', 'https://reseller.c-data.co.il/geforce-gtx-1650-4gb-xlr8-gaming', 'https://reseller.c-data.co.il/geforce-rtx-3090-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/rtx-2080-ti-11gb-xlr8-gaming-overclocked-edition', 'https://reseller.c-data.co.il/geforce-rtx-3070-epic-x-rgb-triple-fan-xlr8-gaming-edition', 'https://reseller.c-data.co.il/gtx-1660-xlr8-gaming-overclocked-single-fan', 'https://reseller.c-data.co.il/rtx-2060-super-twin-fan8gb-gddr6-256-bit', 'https://reseller.c-data.co.il/gtx-1660-super-single-fan-%D7%A2%D7%95%D7%AA%D7%A7', 'https://reseller.c-data.co.il/rtx-2080-super-blower8gb-gddr6-256-bit']
# 2020-11-05 22:17:16.857889 (delta = 0:00:01.354727) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/gtx-1660-xlr8-gaming-overclocked-single-fan-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. GTX 1660 SUPER SINGLE FAN
# 2020-11-05 22:17:17.126168 (delta = 0:00:00.268279) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:17:17.129162 (delta = 0:00:00.002994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:17:17.131156 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:17:19.271004 (delta = 0:00:02.139848) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/geforce-rtx-3080-epic-x-rgb-triple-fan-xlr8-gaming-edition
#             Title : C-Data. GeForce RTX™ 3080 EPIC-X RGB™ Triple Fan XLR8 Gaming Edition
# 2020-11-05 22:17:19.298940 (delta = 0:00:00.027936) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:17:19.301923 (delta = 0:00:00.002983) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:17:19.303917 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:17:21.060013 (delta = 0:00:01.756096) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/gtx-1660-ti-xlr8-gaming-overclocked-single-fan
#             Title : C-Data. GTX 1660 Ti XLR8 Gaming Overclocked Single Fan
# 2020-11-05 22:17:21.124839 (delta = 0:00:00.064826) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:17:21.125835 (delta = 0:00:00.000996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:17:21.127831 (delta = 0:00:00.001996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:17:23.042860 (delta = 0:00:01.915029) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/pny-geforce-gtx-1650-4gb-dual-fan-4gb-gddr6-128-bit
#             Title : C-Data. PNY GEFORCE® GTX 1650 4GB Dual Fan 4GB GDDR6 128-bit
# 2020-11-05 22:17:23.193455 (delta = 0:00:00.150595) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku VCG16504D6DFPPB ---
# 2020-11-05 22:17:23.217392 (delta = 0:00:00.023937) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $174.00
#
# 2020-11-05 22:17:23.282223 (delta = 0:00:00.064831) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 712.53
# 2020-11-05 22:17:23.284213 (delta = 0:00:00.001990) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 710
# 2020-11-05 22:17:24.545940 (delta = 0:00:01.261727) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = VCG16504D6DFPPB
# 2020-11-05 22:17:24.578851 (delta = 0:00:00.032911) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,109,501', 'Supplier Reference': 'VCG16504D6DFPPB', 'Reference': 'CDT-VCG16504D6DFPPB', 'manufacrurer reference': 'VCG16504D6DFPPB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'PNY GEFORCE® GTX 1650 4GB DUAL FAN 4GB GDDR6 128-BIT', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '710', 'Supplier Price (Tax Excl.)': '174.0', 'brand': 'NVIDIA', 'Short Description': 'PNY GEFORCE® GTX 1650 4GB Dual Fan 4GB GDDR6 128-bit', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יצרן                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">PNY                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                גודל תצוגה מסונן                            </td>                            <td class="spec-value"><p><a href="https://www.pny.eu/consumer/explore-all-products/graphics-cards/1094-geforce-gtx-1650-xlr8-gaming-overclocked-single-fan" data-andiallelmwithtext="16" class="UAjgpMEXEX">https://www.pny.eu/consumer/explore-all-products/graphics-cards/1094-geforce-gtx-1650-xlr8-gaming-overclocked-single-fan</a></p>                            </td>                        </tr>                </tbody>', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0006928_pny-geforce-gtx-1650-4gb-dual-fan-4gb-gddr6-128-bit_600.png', 'Imgs alt. text': 'VCG16504D6DFPPB PNY GEFORCE® GTX 1650 4GB DUAL FAN 4GB GDDR6 128-BIT', 'delete old images': '1', 'meta_words': 'NVIDIA VCG16504D6DFPPB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:17:24.580847 (delta = 0:00:00.001996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,109,501', 'Supplier Reference': 'VCG16504D6DFPPB', 'Reference': 'CDT-VCG16504D6DFPPB', 'manufacrurer reference': 'VCG16504D6DFPPB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'PNY GEFORCE® GTX 1650 4GB DUAL FAN 4GB GDDR6 128-BIT', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '710', 'Supplier Price (Tax Excl.)': '174.0', 'brand': 'NVIDIA', 'Short Description': 'PNY GEFORCE® GTX 1650 4GB Dual Fan 4GB GDDR6 128-bit', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יצרן                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">PNY                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                גודל תצוגה מסונן                            </td>                            <td class="spec-value"><p><a href="https://www.pny.eu/consumer/explore-all-products/graphics-cards/1094-geforce-gtx-1650-xlr8-gaming-overclocked-single-fan" data-andiallelmwithtext="16" class="UAjgpMEXEX">https://www.pny.eu/consumer/explore-all-products/graphics-cards/1094-geforce-gtx-1650-xlr8-gaming-overclocked-single-fan</a></p>                            </td>                        </tr>                </tbody>', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0006928_pny-geforce-gtx-1650-4gb-dual-fan-4gb-gddr6-128-bit_600.png', 'Imgs alt. text': 'VCG16504D6DFPPB PNY GEFORCE® GTX 1650 4GB DUAL FAN 4GB GDDR6 128-BIT', 'delete old images': '1', 'meta_words': 'NVIDIA VCG16504D6DFPPB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:17:24.582843 (delta = 0:00:00.001996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:17:26.693214 (delta = 0:00:02.110371) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/-gtx-1650-super-4gb
#             Title : C-Data. ® GTX 1650 SUPER™ 4GB
# 2020-11-05 22:17:26.724132 (delta = 0:00:00.030918) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:17:26.726127 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:17:26.727124 (delta = 0:00:00.000997) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:17:29.126814 (delta = 0:00:02.399690) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/rtx-2070-super-xlr8-oc-triple-fan8gb-gddr6-256-bitpci-e-30-x16
#             Title : C-Data. RTX 2070 SUPER XLR8 OC TRIPLE FAN 8GB GDDR6
# 2020-11-05 22:17:29.154740 (delta = 0:00:00.027926) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:17:29.156735 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:17:29.158733 (delta = 0:00:00.001998) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:17:31.245279 (delta = 0:00:02.086546) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/geforce-gtx-1650-4gb-xlr8-gaming
#             Title : C-Data. GTX 1650 4GB XLR8 Gaming
# 2020-11-05 22:17:31.505570 (delta = 0:00:00.260291) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:17:31.507563 (delta = 0:00:00.001993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:17:31.510556 (delta = 0:00:00.002993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:17:33.641609 (delta = 0:00:02.131053) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/geforce-rtx-3090-epic-x-rgb-triple-fan-xlr8-gaming-edition
#             Title : C-Data. GeForce RTX™ 3090 EPIC-X RGB™ Triple Fan XLR8 Gaming Edition
# 2020-11-05 22:17:33.794199 (delta = 0:00:00.152590) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:17:33.796197 (delta = 0:00:00.001998) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:17:33.797191 (delta = 0:00:00.000994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:17:35.608512 (delta = 0:00:01.811321) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/rtx-2080-ti-11gb-xlr8-gaming-overclocked-edition
#             Title : C-Data. PNY RTX™ 2080 Ti 11GB XLR8 Gaming Overclocked Edition
# 2020-11-05 22:17:35.975530 (delta = 0:00:00.367018) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# ...
# 2020-11-05 22:19:45.069753 (delta = 0:00:00.001992) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:19:48.273436 (delta = 0:00:03.203683) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/geforce-gt-1030
#             Title : C-Data. PNY GeForce® GT 1030
# 2020-11-05 22:19:48.488244 (delta = 0:00:00.214808) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku GF1030GTLF2GEPB ---
# 2020-11-05 22:19:48.532128 (delta = 0:00:00.043884) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена
#                     $93.00
#
# 2020-11-05 22:19:48.634852 (delta = 0:00:00.102724) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена до округления 380.835
# 2020-11-05 22:19:48.636848 (delta = 0:00:00.001996) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   цена после округления 380
# 2020-11-05 22:19:49.603146 (delta = 0:00:00.966298) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   p_fields['Supplier Reference'] = GF1030GTLF2GEPB
# 2020-11-05 22:19:49.641046 (delta = 0:00:00.037900) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:  p_fields = {'category': '1,2,108,111,586', 'Supplier Reference': 'GF1030GTLF2GEPB', 'Reference': 'CDT-GF1030GTLF2GEPB', 'manufacrurer reference': 'GF1030GTLF2GEPB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'PNY GEFORCE® GT 1030', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '380', 'Supplier Price (Tax Excl.)': '93.0', 'brand': 'PNY', 'Short Description': 'PNY GeForce® GT 1030', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יצרן                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">PNY                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                המוצר באתר היצרן                            </td>                            <td class="spec-value">                            </td>                        </tr>                </tbody>', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0002524_pny-geforce-gt-1030_600.png', 'Imgs alt. text': 'GF1030GTLF2GEPB PNY GEFORCE® GT 1030', 'delete old images': '1', 'meta_words': 'PNY GF1030GTLF2GEPB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:19:49.643041 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data {'category': '1,2,108,111,586', 'Supplier Reference': 'GF1030GTLF2GEPB', 'Reference': 'CDT-GF1030GTLF2GEPB', 'manufacrurer reference': 'GF1030GTLF2GEPB', 'Available for Order': '1', 'Condition': 'new', 'show_price': '1', 'Product Name': 'PNY GEFORCE® GT 1030', 'Tax rules ID': '53', 'Supplier': 'CData', 'Visibility': 'both', 'Price': '380', 'Supplier Price (Tax Excl.)': '93.0', 'brand': 'PNY', 'Short Description': 'PNY GeForce® GT 1030', 'Description': '<p font-size="x-small" color="" >upd: 05/11</p>                <colgroup>                    <col width="25%">                    <col>                </colgroup>                <tbody>                        <tr class="odd">                            <td class="spec-name" data-andiallelmwithtext="16">                                יצרן                            </td>                            <td class="spec-value" data-andiallelmwithtext="16">PNY                            </td>                        </tr>                        <tr class="even">                            <td class="spec-name" data-andiallelmwithtext="16">                                המוצר באתר היצרן                            </td>                            <td class="spec-value">                            </td>                        </tr>                </tbody>', 'Product Images': 'https://cdata.b-cdn.net//content/images/thumbs/0002524_pny-geforce-gt-1030_600.png', 'Imgs alt. text': 'GF1030GTLF2GEPB PNY GEFORCE® GT 1030', 'delete old images': '1', 'meta_words': 'PNY GF1030GTLF2GEPB ', 'Active': 1, 'RAW_PAGE_SOURCE': ''}
# 2020-11-05 22:19:49.644035 (delta = 0:00:00.000994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   ############ ТОВАР добавлен
# 2020-11-05 22:19:52.185634 (delta = 0:00:02.541599) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/gtx-1660-super-single-fan-%D7%A2%D7%95%D7%AA%D7%A7
#             Title : C-Data. GTX 1660 SUPER TWIN FAN
# 2020-11-05 22:19:52.402056 (delta = 0:00:00.216422) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:19:52.404049 (delta = 0:00:00.001993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:19:52.406050 (delta = 0:00:00.002001) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:19:54.592056 (delta = 0:00:02.186006) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/rtx-2080-super-blower8gb-gddr6-256-bit
#             Title : C-Data. RTX 2080 SUPER™ Blower Design
# 2020-11-05 22:19:54.870313 (delta = 0:00:00.278257) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:19:54.873304 (delta = 0:00:00.002991) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:19:54.875298 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:19:56.339058 (delta = 0:00:01.463760) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/pny-titan-rtx-24gb-gddr6-hdmi-3x-dp-usb-c
#             Title : C-Data. PNY Titan RTX, 24GB GDDR6, HDMI, 3x DP, USB-C
# 2020-11-05 22:19:56.751954 (delta = 0:00:00.412896) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:19:56.754946 (delta = 0:00:00.002992) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:19:56.756939 (delta = 0:00:00.001993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:19:56.758935 (delta = 0:00:00.001996) 	 : 	 get_all->flush_p->write:
#         LOG STR:   -----------------
#             скидываю товары в файл CDT-PNY.csv
#     -------------
# 2020-11-05 22:19:56.775889 (delta = 0:00:00.016954) 	 : 	 flush_p->export->write:
#         LOG STR:   Данные экспортированы в файл
#        ..\export\CDT-PNY.csv
# 2020-11-05 22:19:56.777884 (delta = 0:00:00.001995) 	 : 	 get_all->flush_p->write:
#         LOG STR:  OK!
# 2020-11-05 22:19:56.779879 (delta = 0:00:00.001995) 	 : 	 get_all->flush_p->write:
#         LOG STR:   -----------------
#             скидываю товары в файл CDT-PNY.csv
#     -------------
# 2020-11-05 22:19:56.793842 (delta = 0:00:00.013963) 	 : 	 flush_p->export->write:
#         LOG STR:   Данные экспортированы в файл
#        ..\export\CDT-PNY.csv
# 2020-11-05 22:19:56.796833 (delta = 0:00:00.002991) 	 : 	 get_all->flush_p->write:
#         LOG STR:  OK!
# 2020-11-05 22:19:59.438769 (delta = 0:00:02.641936) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/%D7%9E%D7%A6%D7%9C%D7%9E%D7%95%D7%AA#/manFilters=1
#             Title : C-Data. מצלמות רשת
# 2020-11-05 22:20:01.006648 (delta = 0:00:01.567879) 	 : 	 sozdaj_ssylki_na_tovary->sozdaj_spisok_ssylok_na_stranicy_tovarov_so_stranicy_kategorii->write:
#         LOG STR:   Собрал со страницы категории ссылки на товары:
#     ['https://reseller.c-data.co.il/lifecam-hd-3000-usb', 'https://reseller.c-data.co.il/lifecam-hd-3000-usb', 'https://reseller.c-data.co.il/lifecam-hd-3000-usb', 'https://reseller.c-data.co.il/LifeCam-HD-3000-USB-for-Bsnss-2', 'https://reseller.c-data.co.il/LifeCam-HD-3000-USB-for-Bsnss-2', 'https://reseller.c-data.co.il/LifeCam-HD-3000-USB-for-Bsnss-2', 'https://reseller.c-data.co.il/LifeCam-Cinema-USB-2', 'https://reseller.c-data.co.il/LifeCam-Cinema-USB-2', 'https://reseller.c-data.co.il/LifeCam-Cinema-USB-2', 'https://reseller.c-data.co.il/lifecam-cinema-for-business', 'https://reseller.c-data.co.il/lifecam-cinema-for-business', 'https://reseller.c-data.co.il/lifecam-cinema-for-business', 'https://reseller.c-data.co.il/LifeCam-Studio-USB-2', 'https://reseller.c-data.co.il/LifeCam-Studio-USB-2', 'https://reseller.c-data.co.il/LifeCam-Studio-USB-2', 'https://reseller.c-data.co.il/lifecam-studio-for-business', 'https://reseller.c-data.co.il/lifecam-studio-for-business', 'https://reseller.c-data.co.il/lifecam-studio-for-business']
# 2020-11-05 22:20:16.524439 (delta = 0:00:15.517791) 	 : 	 click_to_next_page->find->write:
#         LOG STR:  TimeoutException -
#  Message:
#
#
#  Предположительно не нашелся элемент ('css selector', 'li.next-page a')
# 2020-11-05 22:20:16.533382 (delta = 0:00:00.008943) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   собранны ссылки на товары : ['https://reseller.c-data.co.il/lifecam-studio-for-business', 'https://reseller.c-data.co.il/lifecam-hd-3000-usb', 'https://reseller.c-data.co.il/LifeCam-Studio-USB-2', 'https://reseller.c-data.co.il/LifeCam-Cinema-USB-2', 'https://reseller.c-data.co.il/LifeCam-HD-3000-USB-for-Bsnss-2', 'https://reseller.c-data.co.il/lifecam-cinema-for-business']
# 2020-11-05 22:20:18.202983 (delta = 0:00:01.669601) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/lifecam-studio-for-business
#             Title : C-Data. LifeCam Studio For Business
# 2020-11-05 22:20:18.488219 (delta = 0:00:00.285236) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:20:18.491211 (delta = 0:00:00.002992) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:20:18.493206 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:20:20.493335 (delta = 0:00:02.000129) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/lifecam-hd-3000-usb
#             Title : C-Data. LifeCam HD-3000 USB
# 2020-11-05 22:20:20.719730 (delta = 0:00:00.226395) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:20:20.721723 (delta = 0:00:00.001993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:20:20.723717 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:20:22.145339 (delta = 0:00:01.421622) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/LifeCam-Studio-USB-2
#             Title : C-Data. LifeCam Studio - USB
# 2020-11-05 22:20:22.588154 (delta = 0:00:00.442815) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:20:22.590663 (delta = 0:00:00.002509) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:20:22.592660 (delta = 0:00:00.001997) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:20:24.438639 (delta = 0:00:01.845979) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/LifeCam-Cinema-USB-2
#             Title : C-Data. LifeCam Cinema - USB
# 2020-11-05 22:20:24.473546 (delta = 0:00:00.034907) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:20:24.475541 (delta = 0:00:00.001995) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:20:24.478534 (delta = 0:00:00.002993) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:20:26.848526 (delta = 0:00:02.369992) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/LifeCam-HD-3000-USB-for-Bsnss-2
#             Title : C-Data. LifeCam HD-3000 USB for Business
# 2020-11-05 22:20:27.176646 (delta = 0:00:00.328120) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:20:27.179636 (delta = 0:00:00.002990) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:20:27.181630 (delta = 0:00:00.001994) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:20:28.991827 (delta = 0:00:01.810197) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://reseller.c-data.co.il/lifecam-cinema-for-business
#             Title : C-Data. LifeCam Cinema For Business
# 2020-11-05 22:20:29.186302 (delta = 0:00:00.194475) 	 : 	 sozdaj_spisok_tovarov->get_all->write:
#         LOG STR:   -- нет в наличии   ---
# 2020-11-05 22:20:29.188298 (delta = 0:00:00.001996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:  product_data False
# 2020-11-05 22:20:29.189294 (delta = 0:00:00.000996) 	 : 	 get_all->sozdaj_spisok_tovarov->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2020-11-05 22:20:29.191288 (delta = 0:00:00.001994) 	 : 	 get_all->flush_p->write:
#         LOG STR:   -----------------
#             скидываю товары в файл CDT-Cams MICROSOFT.csv
#     -------------
# 2020-11-05 22:20:29.206248 (delta = 0:00:00.014960) 	 : 	 flush_p->export->write:
#         LOG STR:   Данные экспортированы в файл
#        ..\export\CDT-Cams MICROSOFT.csv
# 2020-11-05 22:20:29.208243 (delta = 0:00:00.001995) 	 : 	 get_all->flush_p->write:
#         LOG STR:  OK!
# 2020-11-05 22:20:29.210239 (delta = 0:00:00.001996) 	 : 	 get_all->flush_p->write:
#         LOG STR:   -----------------
#             скидываю товары в файл CDT-Cams MICROSOFT.csv
#     -------------
# 2020-11-05 22:20:29.224201 (delta = 0:00:00.013962) 	 : 	 flush_p->export->write:
#         LOG STR:   Данные экспортированы в файл
#        ..\export\CDT-Cams MICROSOFT.csv
# 2020-11-05 22:20:29.226196 (delta = 0:00:00.001995) 	 : 	 get_all->flush_p->write:
#         LOG STR:  OK!
# 2020-11-05 22:20:29.227193 (delta = 0:00:00.000997) 	 : 	 export_products_by_scenaries->execute_list_of_scenaries->write:
#         LOG STR:   -=OK!=-
# 2020-11-05 22:20:29.229188 (delta = 0:00:00.001995) 	 : 	 flush_p->flush_p->write:
#         LOG STR:   -----------------
#             скидываю товары в файл CDT-Cams MICROSOFT.csv
#     -------------
# 2020-11-05 22:20:29.244147 (delta = 0:00:00.014959) 	 : 	 flush_p->export->write:
#         LOG STR:   Данные экспортированы в файл
#        ..\export\CDT-Cams MICROSOFT.csv
# 2020-11-05 22:20:29.246142 (delta = 0:00:00.001995) 	 : 	 flush_p->flush_p->write:
#         LOG STR:  OK!
