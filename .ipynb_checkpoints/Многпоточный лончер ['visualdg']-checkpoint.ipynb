# %%
import main
main.run(['cdata'])
# Out:
# 2021-04-19 16:47:44.893289 (delta = 0:00:00.004000) 	 : 	 __init__->__init__->write:
#         LOG STR:   supplier_settings = <module 'suppliers.cdata' from 'C:\\Users\\onela\\OneDrive\\REPOS\\Aluf\\Aluf\\suppliers\\cdata\\__init__.py'>
# 2021-04-19 16:47:44.894289 (delta = 0:00:00.001000) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс cdata
# 2021-04-19 16:47:44.896290 (delta = 0:00:00.002001) 	 : 	 run->run->write:
#         LOG STR:
# 2021-04-19 16:47:51.245882 (delta = 0:00:06.349592) 	 : 	 run->get_url->write:
#         LOG STR:  https://c-data.co.il/
# 2021-04-19 16:47:52.680362 (delta = 0:00:01.434480) 	 : 	 log_in->get_url->write:
#         LOG STR:  https://reseller.c-data.co.il/Login
# 2021-04-19 16:47:55.152668 (delta = 0:00:02.472306) 	 : 	 run->log_in->write:
#         LOG STR:  C-data logged in
# 2021-04-19 16:47:57.556854 (delta = 0:00:02.404186) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
# ...
