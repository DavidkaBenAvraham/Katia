# %%
import main

suppliers_names = ['cdata','mor','grand','vdg']
one_supplier = ['grand']
scenario = ["grandadvance_categories_keyboards_logitech.json"]
scenario = [ "grandadvance_categories_laptops_acer.json",
    "grandadvance_categories_laptops_lenovo.json",
    "grandadvance_categories_laptops_hp.json",
    "grandadvance_categories_laptops_dell.json"]
scenario = [ "grandadvance_categories_laptops_acer.json",
    "grandadvance_categories_laptops_lenovo.json",
    "grandadvance_categories_laptops_hp.json",
    "grandadvance_categories_laptops_dell.json"]

scenario = [ "grandadvance_categories_laptops_acer.json"]
for supplier_name in one_supplier:
    supplier = main.run_supplier(supplier_name)
    if supplier != False: main.run_scenario(supplier , scenario)
# Out:
# 2020-11-24 10:48:34.564520 (delta = 0:00:00.001001) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс Driver()
# 2020-11-24 10:48:41.847149 (delta = 0:00:07.282629) 	 : 	 run_supplier->__init__->write:
#         LOG STR:  запустился класс Гранд
# 2020-11-24 10:48:44.691786 (delta = 0:00:02.844637) 	 : 	 run->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.grandadvance.co.il/
#             Title : Grand Advance Computers Ltd. (since 1988)
# 2020-11-24 10:48:44.692786 (delta = 0:00:00.001000) 	 : 	 run->logged_in->write:
#         LOG STR:  Залогиниваюсь
# 2020-11-24 10:48:46.366162 (delta = 0:00:01.673376) 	 : 	 run->logged_in->write:
#         LOG STR:  Гранд logged in
# 2020-11-24 10:48:47.383387 (delta = 0:00:01.017225) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.grandadvance.co.il/default.aspx?g=products&a=list&tieId=585&manId=10
# ...
