# %%
import main
main.run(['cdata'])
# Out:
# 2021-04-26 11:19:23.182406 (delta = 0:00:00.030006) 	 : 	 __init__->__init__->write:
#         LOG STR:   supplier_settings = <module 'suppliers.cdata' from 'C:\\Users\\onela\\OneDrive\\REPOS\\Aluf\\Aluf\\suppliers\\cdata\\__init__.py'>
# 2021-04-26 11:19:23.183407 (delta = 0:00:00.001001) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс cdata
# 2021-04-26 11:19:23.185408 (delta = 0:00:00.002001) 	 : 	 run->run->write:
#         LOG STR:
# 2021-04-26 11:19:36.541409 (delta = 0:00:13.356001) 	 : 	 run->get_url->write:
#         LOG STR:   Current URL: https://c-data.co.il/
# 2021-04-26 11:19:40.500163 (delta = 0:00:03.958754) 	 : 	 log_in->get_url->write:
#         LOG STR:   Current URL: https://reseller.c-data.co.il/Login
# 2021-04-26 11:19:44.593294 (delta = 0:00:04.093131) 	 : 	 run->log_in->write:
#         LOG STR:  C-data logged in
# 2021-04-26 11:19:44.594294 (delta = 0:00:00.001000) 	 : 	 run->run->write:
#         LOG STR:   Начинаю выполнять сценарии
# ...
