# %%
from IPython.core.display import display, HTML
import main
main.run()
# Out:
#
#         <html>
#
#         <header><styles>
#                     a{font-size:16px}
#                     .info{
#                             text-decoration: none;
#                             color:blue;
#                             font-size:xx-small;
#                             }
#                     </styles>
#             <script>
#             function view(r) {
#                 style = document.getElementById(r).style;
#                 style.display = (style.display == 'block') ? 'none' : 'block';
#                 }
#         </script>
#
#         </header>
# {'name': 'firefox', 'arguments': ['--no-sandbox'], 'disabled_arguments': ['--disable-dev-shm-usage', '--headless'], 'driver_wait': 5}
#             <p>
#                 <a href="#hidden_67055773" onclick="view('hidden_67055773'); return false"
#                 style="color:green;text-decoration: none;">
#                           (+ attr)  -------------->
#                 </a>
#             </p>
#
# ...

# %% [markdown]
# #
