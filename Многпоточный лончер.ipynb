# %%
from IPython.core.display import display, HTML
import main
main.run(threads = False)
# Out:
# functionsfunction view(n) {  style = document.getElementById(n).style;  style.display = (style.display == 'block') ? 'none' : 'block';}
#
#
#             +->run_code->->run->__init__->__init__->->
#
#
#
#
#             args:
#             kwargs:
#
#
#
#
#             +->run_ast_nodes->run_code->->run->__init__->->
#
#
#
#
#             args:
#             kwargs:
#
#
#
#
#             +->run_cell_async->run_ast_nodes->run_code->->run->->
#
#
#
#
#             args:
#             kwargs:
#
#
#
#
#             +->run_code->->run->run->->
#
#
#
#
#             args:1.https://www.ksp.co.il/
#             kwargs:
#
#
# Страница загрузилась : https://ksp.co.il/web/
#
#
#             +->run_code->->run->run->->
#
#
#
#
#             args:
#             kwargs:
#
#
#
#
#             +->run->run->execute_list_of_scenaries->->
#
#
#
#
#             args:
#             kwargs:
#
#
#
#
#             +->run->execute_list_of_scenaries->run_scenario->->
#
#
#
#
#             args:
# ...

# %% [markdown]
# #
