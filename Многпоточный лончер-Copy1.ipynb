# %%
import main
main.run()
# Out:
# 2021-05-04 20:25:51.811513 (delta = 0:00:00.006001) 	 : 	 __init__->__init__->write:
#         LOG STR:   supplier_settings = <module 'suppliers.cdata' from 'C:\\Users\\onela\\OneDrive\\REPOS\\Aluf\\Aluf\\suppliers\\cdata\\__init__.py'>  supplier_class:
# ...
# 2021-05-04 20:25:51.812513 (delta = 0:00:00.001000) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс cdata supplier_class:
# ...
# 2021-05-04 20:25:51.814514 (delta = 0:00:00.002001) 	 : 	 run->get_url->write:
#         LOG STR:
#             Ошибка 'Supplier' object has no attribute 'driver'
#             по адресу https://www.c-data.co.il/  supplier_class:
# ...
# 2021-05-04 20:25:51.819515 (delta = 0:00:00.005001) 	 : 	 log_in->get_url->write:
#         LOG STR:
#             Ошибка 'Supplier' object has no attribute 'driver'
#             по адресу https://reseller.c-data.co.il/Login  supplier_class:
# ...
# 2021-05-04 20:25:51.819515 (delta = 0:00:00) 	 : 	 log_in->find->write:
# ...
