# %%
import main

suppliers_names = ['cdata','mor','grand','vdg']
one_supplier = ['vdg']

minipc = ["visualdg_categories_minipc_asus.json"]
mb = ["visualdg_categories_mb_asus.json"]
monitors = ["visualdg_categories_monitors_asus.json"]
video =["visualdg_categories_monitors_asus.json","visualdg_categories_video_asus.json"]

laptops = [ "visualdg_categories_laptops_asus.json",
    "visualdg_categories_laptops_lenovo_thinkbook.json",
    "visualdg_categories_laptops_lenovo_thinkpad_e.json",
    "visualdg_categories_laptops_lenovo_thinkpad_l.json",
    "visualdg_categories_laptops_lenovo_thinkpad_p.json",
    "visualdg_categories_laptops_lenovo_thinkpad_t.json",
    "visualdg_categories_laptops_lenovo_thinkpad_x.json",
    "visualdg_categories_laptops_lenovo_v_essentials.json",
    "visualdg_categories_laptops_lenovo_yoga.json"]

scenaries = [minipc,mb,monitors,video,laptops]

for scenario in scenaries: 
    supplier = main.run_supplier('vdg')
    main.run_scenario(supplier , scenario)
# Out:
# 2021-04-11 12:18:11.275297 (delta = 0:00:00.000999) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс Driver()
# 2021-04-11 12:18:21.092836 (delta = 0:00:09.817539) 	 : 	 run_supplier->__init__->write:
#         LOG STR:  запустился класс vdg
# 2021-04-11 12:18:30.571253 (delta = 0:00:09.478417) 	 : 	 run->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/
#             Title : Visual D.G - Visual D.G. | ויזואל ד.ג
# 2021-04-11 12:18:53.070032 (delta = 0:00:22.498779) 	 : 	 logged_in->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/customer_login
#             Title : כניסת לקוחות
# 2021-04-11 12:18:55.857537 (delta = 0:00:02.787505) 	 : 	 run->logged_in->write:
#         LOG STR:  VDG logged in
# 2021-04-11 12:18:58.046264 (delta = 0:00:02.188727) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
# ...
