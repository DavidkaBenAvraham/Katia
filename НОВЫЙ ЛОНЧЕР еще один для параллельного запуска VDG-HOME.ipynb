# %%
import main

suppliers_names = ['cdata','mor','grand','vdg']
one_supplier = ['vdg']
scenario = [    "visualdg_categories_minipc_asus.json",
    "visualdg_categories_mb_asus.json",
    "visualdg_categories_monitors_asus.json"]

scenario =["visualdg_categories_monitors_asus.json","visualdg_categories_video_asus.json"]
scenario = ["visualdg_categories_video_asus.json"]

scenario = [ "visualdg_categories_laptops_asus.json",
    "visualdg_categories_laptops_lenovo_thinkbook.json",
    "visualdg_categories_laptops_lenovo_thinkpad_e.json",
    "visualdg_categories_laptops_lenovo_thinkpad_l.json",
    "visualdg_categories_laptops_lenovo_thinkpad_p.json",
    "visualdg_categories_laptops_lenovo_thinkpad_t.json",
    "visualdg_categories_laptops_lenovo_thinkpad_x.json",
    "visualdg_categories_laptops_lenovo_v_essentials.json",
    "visualdg_categories_laptops_lenovo_yoga.json"]


for supplier_name in one_supplier:
    supplier = main.run_supplier(supplier_name)
    if supplier != False: main.run_scenario(supplier , scenario)
# Out:
# 2021-02-05 11:28:02.598218 (delta = 0:00:00.001995) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс Driver()
# 2021-02-05 11:28:11.909372 (delta = 0:00:09.311154) 	 : 	 run_supplier->__init__->write:
#         LOG STR:  запустился класс vdg
# 2021-02-05 11:28:17.698336 (delta = 0:00:05.788964) 	 : 	 run->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/
#             Title : Visual D.G - Visual D.G. | ויזואל ד.ג
# 2021-02-05 11:28:20.602947 (delta = 0:00:02.904611) 	 : 	 logged_in->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/customer_login
#             Title : כניסת לקוחות
# 2021-02-05 11:28:22.995340 (delta = 0:00:02.392393) 	 : 	 run->logged_in->write:
#         LOG STR:  VDG logged in
# 2021-02-05 11:28:23.011299 (delta = 0:00:00.015959) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------------------------ASUS 11.6 I3 ----------------------------
#                 EXCEPTION :   Message: Malformed URL: URL constructor: --------------------------------ASUS 11.6 I3 ---------------------------- is not a valid URL.
#
# 2021-02-05 11:28:23.013294 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:23.014291 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------------------------ASUS 11.6 I3 ----------------------------
# 2021-02-05 11:28:23.018280 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -----------ASUS 11.6 I5-------------------
#                 EXCEPTION :   Message: Malformed URL: URL constructor: -----------ASUS 11.6 I5------------------- is not a valid URL.
#
# 2021-02-05 11:28:23.020276 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:23.021273 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -----------ASUS 11.6 I5-------------------
# 2021-02-05 11:28:23.025263 (delta = 0:00:00.003990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------ASUS 11.6 I7-----------------
#                 EXCEPTION :   Message: Malformed URL: URL constructor: --------------ASUS 11.6 I7----------------- is not a valid URL.
#
# 2021-02-05 11:28:23.026259 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:23.027255 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------ASUS 11.6 I7-----------------
# 2021-02-05 11:28:23.032244 (delta = 0:00:00.004989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -------------ASUS 11.6 I9----------------
#                 EXCEPTION :   Message: Malformed URL: URL constructor: -------------ASUS 11.6 I9----------------  is not a valid URL.
#
# 2021-02-05 11:28:23.033242 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:23.034237 (delta = 0:00:00.000995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -------------ASUS 11.6 I9----------------
# 2021-02-05 11:28:23.039225 (delta = 0:00:00.004988) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -------------ASUS 11.6 AMD----------------
#                 EXCEPTION :   Message: Malformed URL: URL constructor: -------------ASUS 11.6 AMD----------------  is not a valid URL.
#
# 2021-02-05 11:28:23.040221 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:23.041222 (delta = 0:00:00.001001) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -------------ASUS 11.6 AMD----------------
# 2021-02-05 11:28:23.875988 (delta = 0:00:00.834766) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253280/253293
#             Title : עבור לדף המבוקש
# 2021-02-05 11:28:23.884972 (delta = 0:00:00.008984) 	 : 	 get_all->sozdaj_ssylki_na_tovary->write:
#         LOG STR:   עבור לדף המבוקש
# 2021-02-05 11:28:25.161790 (delta = 0:00:01.276818) 	 : 	 get_all->sozdaj_ssylki_na_tovary->write:
#         LOG STR:   עבור לדף המבוקש
# 2021-02-05 11:28:25.258724 (delta = 0:00:00.096934) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:        Успешный переход по адресу: https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253280/253293
#             Title : עבור לדף המבוקש
# 2021-02-05 11:28:25.262709 (delta = 0:00:00.003985) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки
# 2021-02-05 11:28:25.264705 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   собранны ссылки на товары :
# 2021-02-05 11:28:25.270689 (delta = 0:00:00.005984) 	 : 	 sozdaj_spisok_tovarov->get_url->write:
#         LOG STR:   Не получен адрес
#                 EXCEPTION :   Message: Malformed URL: URL constructor:  is not a valid URL.
#
# 2021-02-05 11:28:32.099816 (delta = 0:00:06.829127) 	 : 	 nalihie_segodnja->get_attribute_from_first_found_element->write:
#         LOG STR:  Message: Failed to convert data to an object
#
# 2021-02-05 11:28:32.101810 (delta = 0:00:00.001994) 	 : 	 nalihie_segodnja->get_attribute_from_first_found_element->write:
#         LOG STR:  Не нашел элемент по локатору ('css selector', 'span.stock_text')
# 2021-02-05 11:28:32.123751 (delta = 0:00:00.021941) 	 : 	 get_sku->get_attribute_from_first_found_element->write:
#         LOG STR:  Message: Browsing context has been discarded
#
# 2021-02-05 11:28:32.124750 (delta = 0:00:00.000999) 	 : 	 get_sku->get_attribute_from_first_found_element->write:
#         LOG STR:  Не нашел элемент по локатору ('css selector', 'div.code_item')
# 2021-02-05 11:28:32.126742 (delta = 0:00:00.001992) 	 : 	 get_all->get_sku->write:
#         LOG STR:       --- sku False ---
# 2021-02-05 11:28:33.947153 (delta = 0:00:01.820411) 	 : 	 get_price->get_attribute_from_first_found_element->write:
#         LOG STR:  Message: Failed to decode response from marionette
#
# 2021-02-05 11:28:33.949161 (delta = 0:00:00.002008) 	 : 	 get_price->get_attribute_from_first_found_element->write:
#         LOG STR:  Не нашел элемент по локатору ('css selector', 'span.price_value')
# 2021-02-05 11:28:33.951140 (delta = 0:00:00.001979) 	 : 	 get_all->get_price->write:
#         LOG STR:   найдена цена False
# 2021-02-05 11:28:33.954137 (delta = 0:00:00.002997) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:    - Потряна связь с сайтом
#             EXCEPTION InvalidSessionIdException:
#             Message: Tried to run command without establishing a connection
#
#
# 2021-02-05 11:28:33.957126 (delta = 0:00:00.002989) 	 : 	 get_image->get_attribute_from_first_found_element->write:
#         LOG STR:  Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:33.959120 (delta = 0:00:00.001994) 	 : 	 get_image->get_attribute_from_first_found_element->write:
#         LOG STR:  Не нашел элемент по локатору ('css selector', 'div[id=item_show_carousel] img')
# 2021-02-05 11:28:33.961116 (delta = 0:00:00.001996) 	 : 	 get_attribute_from_first_found_element->find->write:
#         LOG STR:    - Потряна связь с сайтом
#             EXCEPTION InvalidSessionIdException:
#             Message: Tried to run command without establishing a connection
#
#
# 2021-02-05 11:28:33.965103 (delta = 0:00:00.003987) 	 : 	 get_title->get_attribute_from_first_found_element->write:
#         LOG STR:  Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:33.966103 (delta = 0:00:00.001000) 	 : 	 get_title->get_attribute_from_first_found_element->write:
#         LOG STR:  Не нашел элемент по локатору ('css selector', "span[itemprop='name']")
# 2021-02-05 11:28:33.968097 (delta = 0:00:00.001994) 	 : 	 get_all->flush_p->write:
#         LOG STR:   Пустой список продуктов. Нечего записыавть
# 2021-02-05 11:28:33.970090 (delta = 0:00:00.001993) 	 : 	 zapolni_paramerty_tovara->get_all->write:
#         LOG STR:   Скорее всего грохнулась страница товара
# 2021-02-05 11:28:33.971088 (delta = 0:00:00.000998) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:  product_data False
# 2021-02-05 11:28:33.972085 (delta = 0:00:00.000997) 	 : 	 sozdaj_spisok_tovarov->zapolni_paramerty_tovara->write:
#         LOG STR:   проблема при сборе параметров товара . Пропускаю
# 2021-02-05 11:28:33.973082 (delta = 0:00:00.000997) 	 : 	 get_all->flush_p->write:
#         LOG STR:   Пустой список продуктов. Нечего записыавть
# 2021-02-05 11:28:33.976075 (delta = 0:00:00.002993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253279/253293
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:33.977073 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:33.978071 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253279/253293
# 2021-02-05 11:28:33.982058 (delta = 0:00:00.003987) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -------------------ASUS 13.4 - 13.3 I3-----------r
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:33.983057 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:33.985051 (delta = 0:00:00.001994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -------------------ASUS 13.4 - 13.3 I3-----------r
# 2021-02-05 11:28:33.988043 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253294
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:33.991035 (delta = 0:00:00.002992) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:33.992034 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253294
# 2021-02-05 11:28:33.995024 (delta = 0:00:00.002990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253274/253294
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:33.996024 (delta = 0:00:00.001000) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:33.999014 (delta = 0:00:00.002990) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253274/253294
# 2021-02-05 11:28:34.002005 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ------------ASUS 13.4 - 13.3 I9-----------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.004001 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.006991 (delta = 0:00:00.002990) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ------------ASUS 13.4 - 13.3 I9-----------------
# 2021-02-05 11:28:34.009985 (delta = 0:00:00.002994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------ASUS 13.4 - 13.3 AMD------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.010983 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.011980 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------ASUS 13.4 - 13.3 AMD------------------
# 2021-02-05 11:28:34.014969 (delta = 0:00:00.002989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -----------------ASUS 13.4 - 13.3 Celeron----------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.016968 (delta = 0:00:00.001999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.018960 (delta = 0:00:00.001992) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -----------------ASUS 13.4 - 13.3 Celeron----------------
# 2021-02-05 11:28:34.020956 (delta = 0:00:00.001996) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -----------------ASUS 13.4 - 13.3 Pentium ------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.022950 (delta = 0:00:00.001994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.023947 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -----------------ASUS 13.4 - 13.3 Pentium ------------
# 2021-02-05 11:28:34.025942 (delta = 0:00:00.001995) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253272/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.027937 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.028933 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253272/253295
# 2021-02-05 11:28:34.031924 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253295?
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.032925 (delta = 0:00:00.001001) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.034919 (delta = 0:00:00.001994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253295?
# 2021-02-05 11:28:34.037909 (delta = 0:00:00.002990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.038906 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.040901 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253295
# 2021-02-05 11:28:34.042896 (delta = 0:00:00.001995) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.043894 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.044891 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253273/253295
# 2021-02-05 11:28:34.047883 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253281
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.048881 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.050877 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253281
# 2021-02-05 11:28:34.054865 (delta = 0:00:00.003988) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253280/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.055863 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.056859 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253280/253295
# 2021-02-05 11:28:34.059851 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253279/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.060847 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.061845 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253279/253295
# 2021-02-05 11:28:34.065835 (delta = 0:00:00.003990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253272/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.066832 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.069828 (delta = 0:00:00.002996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253272/253296
# 2021-02-05 11:28:34.072817 (delta = 0:00:00.002989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253273/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.073812 (delta = 0:00:00.000995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.074809 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253273/253296
# 2021-02-05 11:28:34.077806 (delta = 0:00:00.002997) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253274/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.078799 (delta = 0:00:00.000993) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.080795 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253274/253296
# 2021-02-05 11:28:34.084784 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253278/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.085782 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.087778 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/253278/253296
# 2021-02-05 11:28:34.090768 (delta = 0:00:00.002990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253281/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.091767 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.092763 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253281/253296
# 2021-02-05 11:28:34.095754 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253280/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.097753 (delta = 0:00:00.001999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.098745 (delta = 0:00:00.000992) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253280/253296
# 2021-02-05 11:28:34.102737 (delta = 0:00:00.003992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253279/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.104731 (delta = 0:00:00.001994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.105727 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253279/253296
# 2021-02-05 11:28:34.108720 (delta = 0:00:00.002993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ---------------ASUS 17.3 I3------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.109717 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.111712 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ---------------ASUS 17.3 I3------------------
# 2021-02-05 11:28:34.115702 (delta = 0:00:00.003990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------ASUS 17.3 I5--------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.116699 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.118694 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------ASUS 17.3 I5--------------
# 2021-02-05 11:28:34.121685 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253274/253297
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.123680 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.124679 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253274/253297
# 2021-02-05 11:28:34.127668 (delta = 0:00:00.002989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253278/253297
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.128669 (delta = 0:00:00.001001) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.130661 (delta = 0:00:00.001992) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169419-%D7%A0%D7%99%D7%99%D7%93%D7%99-ASUS/243216-Asus/253278/253297
# 2021-02-05 11:28:34.135654 (delta = 0:00:00.004993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ------------------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.137642 (delta = 0:00:00.001988) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.139637 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ------------------------------
# 2021-02-05 11:28:34.141633 (delta = 0:00:00.001996) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -----------------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.143625 (delta = 0:00:00.001992) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.144624 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -----------------------------
# 2021-02-05 11:28:34.148613 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ---------------------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.150608 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.152603 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ---------------------------------
# 2021-02-05 11:28:34.153601 (delta = 0:00:00.000998) 	 : 	 get_all->flush_p->write:
#         LOG STR:   Пустой список продуктов. Нечего записыавть
# 2021-02-05 11:28:34.172550 (delta = 0:00:00.018949) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -----------------THINKBOOK 13.4 - 13.3 I3-------------r
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.174546 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.175541 (delta = 0:00:00.000995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -----------------THINKBOOK 13.4 - 13.3 I3-------------r
# 2021-02-05 11:28:34.178534 (delta = 0:00:00.002993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253273/253294
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.180529 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.181526 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253273/253294
# 2021-02-05 11:28:34.185515 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253274/253294
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.187511 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.188508 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253274/253294
# 2021-02-05 11:28:34.192499 (delta = 0:00:00.003991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKBOOK 13.4 - 13.3 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.194504 (delta = 0:00:00.002005) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.195490 (delta = 0:00:00.000986) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKBOOK 13.4 - 13.3 I9-------------
# 2021-02-05 11:28:34.199478 (delta = 0:00:00.003988) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------LENOVO THINKBOOK 13.4 - 13.3 AMD---------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.200475 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.201473 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------LENOVO THINKBOOK 13.4 - 13.3 AMD---------------
# 2021-02-05 11:28:34.204464 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ------------------------LENOVO THINKBOOK 14 I3----------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.206459 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.207458 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ------------------------LENOVO THINKBOOK 14 I3----------------------
# 2021-02-05 11:28:34.210448 (delta = 0:00:00.002990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253273/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.211446 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.212443 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253273/253295
# 2021-02-05 11:28:34.216432 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253274/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.218426 (delta = 0:00:00.001994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.219424 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253274/253295
# 2021-02-05 11:28:34.223413 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKBOOK 14 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.224411 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.226406 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKBOOK 14 I9-------------
# 2021-02-05 11:28:34.229396 (delta = 0:00:00.002990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKBOOK 14 AMD-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.231392 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.233387 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKBOOK 14 AMD-------------
# 2021-02-05 11:28:34.236380 (delta = 0:00:00.002993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKBOOK 15 I3-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.237377 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.238374 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKBOOK 15 I3-------------
# 2021-02-05 11:28:34.241366 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253273/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.243359 (delta = 0:00:00.001993) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.244359 (delta = 0:00:00.001000) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253273/253296
# 2021-02-05 11:28:34.247350 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253274/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.249344 (delta = 0:00:00.001994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.250342 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172332-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkBook-/253274/253296
# 2021-02-05 11:28:34.254331 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKBOOK 15 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.255328 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.257323 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKBOOK 15 I9-------------
# 2021-02-05 11:28:34.260315 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKBOOK 15 AMD-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.263308 (delta = 0:00:00.002993) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.264316 (delta = 0:00:00.001008) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKBOOK 15 AMD-------------
# 2021-02-05 11:28:34.265302 (delta = 0:00:00.000986) 	 : 	 get_all->flush_p->write:
#         LOG STR:   Пустой список продуктов. Нечего записыавть
# 2021-02-05 11:28:34.278168 (delta = 0:00:00.012866) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -----------------THINKPAD E 13.4 - 13.3 I3-------------r
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.280162 (delta = 0:00:00.001994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.281158 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -----------------THINKPAD E 13.4 - 13.3 I3-------------r
# 2021-02-05 11:28:34.285149 (delta = 0:00:00.003991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ---------------------THINKPAD E 13.4 - 13.3 I5---------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.286146 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.287144 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ---------------------THINKPAD E 13.4 - 13.3 I5---------------
# 2021-02-05 11:28:34.289139 (delta = 0:00:00.001995) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ---------------------THINKPAD E 13.4 - 13.3 I7---------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.291134 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.292130 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ---------------------THINKPAD E 13.4 - 13.3 I7---------------
# 2021-02-05 11:28:34.295123 (delta = 0:00:00.002993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKPAD E 13.4 - 13.3 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.296120 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.297117 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKPAD E 13.4 - 13.3 I9-------------
# 2021-02-05 11:28:34.300109 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------LENOVO THINKPAD E 13.4 - 13.3 AMD---------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.301111 (delta = 0:00:00.001002) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.302105 (delta = 0:00:00.000994) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------LENOVO THINKPAD E 13.4 - 13.3 AMD---------------
# 2021-02-05 11:28:34.304099 (delta = 0:00:00.001994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ------------------------LENOVO THINKPAD E 14 I3----------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.305095 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.306093 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ------------------------LENOVO THINKPAD E 14 I3----------------------
# 2021-02-05 11:28:34.309085 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172304-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-E-/253273/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.310083 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.311078 (delta = 0:00:00.000995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172304-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-E-/253273/253295
# 2021-02-05 11:28:34.314072 (delta = 0:00:00.002994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172304-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-E-/253274/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.315068 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.317064 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172304-%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-E-/253274/253295
# 2021-02-05 11:28:34.320056 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKPAD E 14 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:34.321053 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:34.322050 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO THINKPAD E 14 I9-------------
# 2021-02-05 11:28:34.326039 (delta = 0:00:00.003989) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO THINKPAD E 14 AMD-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# ...
# 2021-02-05 11:28:35.106952 (delta = 0:00:00.002994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO V ESSENTIALS 14 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.108947 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.109949 (delta = 0:00:00.001002) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO V ESSENTIALS 14 I9-------------
# 2021-02-05 11:28:35.113934 (delta = 0:00:00.003985) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO V ESSENTIALS 14 AMD-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.115929 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.116926 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO V ESSENTIALS 14 AMD-------------
# 2021-02-05 11:28:35.119918 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO V ESSENTIALS 15 I3-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.121911 (delta = 0:00:00.001993) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.122910 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO V ESSENTIALS 15 I3-------------
# 2021-02-05 11:28:35.125900 (delta = 0:00:00.002990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169443-%D7%A0%D7%99%D7%99%D7%93%D7%99-V-Essential-/253273/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.127895 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.128894 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169443-%D7%A0%D7%99%D7%99%D7%93%D7%99-V-Essential-/253273/253296
# 2021-02-05 11:28:35.132882 (delta = 0:00:00.003988) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------LENOVO V ESSENTIALS 15 I7--------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.133879 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.134876 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------LENOVO V ESSENTIALS 15 I7--------------------
# 2021-02-05 11:28:35.137867 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO V ESSENTIALS 15 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.139864 (delta = 0:00:00.001997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.140861 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO V ESSENTIALS 15 I9-------------
# 2021-02-05 11:28:35.143853 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/169443-%D7%A0%D7%99%D7%99%D7%93%D7%99-V-Essential-/253281/253296
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.144850 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.146846 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/169443-%D7%A0%D7%99%D7%99%D7%93%D7%99-V-Essential-/253281/253296
# 2021-02-05 11:28:35.147842 (delta = 0:00:00.000996) 	 : 	 get_all->flush_p->write:
#         LOG STR:   Пустой список продуктов. Нечего записыавть
# 2021-02-05 11:28:35.161804 (delta = 0:00:00.013962) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес -----------------YOGA 13.4 - 13.3 I3-------------r
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.162805 (delta = 0:00:00.001001) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.163802 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  -----------------YOGA 13.4 - 13.3 I3-------------r
# 2021-02-05 11:28:35.166790 (delta = 0:00:00.002988) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172330--%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-Yoga/253273/253294
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.168785 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.169784 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172330--%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-Yoga/253273/253294
# 2021-02-05 11:28:35.171778 (delta = 0:00:00.001994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172330--%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-Yoga/253274/253294
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.172774 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.173774 (delta = 0:00:00.001000) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172330--%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-Yoga/253274/253294
# 2021-02-05 11:28:35.176764 (delta = 0:00:00.002990) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO YOGA 13.4 - 13.3 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.177765 (delta = 0:00:00.001001) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.178760 (delta = 0:00:00.000995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO YOGA 13.4 - 13.3 I9-------------
# 2021-02-05 11:28:35.181752 (delta = 0:00:00.002992) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------LENOVO YOGA 13.4 - 13.3 AMD---------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.182749 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.183745 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------LENOVO YOGA 13.4 - 13.3 AMD---------------
# 2021-02-05 11:28:35.185740 (delta = 0:00:00.001995) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ------------------------LENOVO YOGA 14 I3----------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.186738 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.187734 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ------------------------LENOVO YOGA 14 I3----------------------
# 2021-02-05 11:28:35.190727 (delta = 0:00:00.002993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ------------------LENOVO YOGA 14 I5---------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.191726 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.192722 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ------------------LENOVO YOGA 14 I5---------------
# 2021-02-05 11:28:35.194716 (delta = 0:00:00.001994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес https://www.visualdg.co.il/172330--%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-Yoga/253274/253295
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.195714 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.197709 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  https://www.visualdg.co.il/172330--%D7%A0%D7%99%D7%99%D7%93%D7%99-ThinkPad-Yoga/253274/253295
# 2021-02-05 11:28:35.199703 (delta = 0:00:00.001994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO YOGA 14 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.200699 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.201699 (delta = 0:00:00.001000) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO YOGA 14 I9-------------
# 2021-02-05 11:28:35.204690 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO YOGA 14 AMD-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.205689 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.206686 (delta = 0:00:00.000997) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO YOGA 14 AMD-------------
# 2021-02-05 11:28:35.208680 (delta = 0:00:00.001994) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO YOGA 15 I3-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.210675 (delta = 0:00:00.001995) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.211673 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO YOGA 15 I3-------------
# 2021-02-05 11:28:35.213666 (delta = 0:00:00.001993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------LENOVO YOGA 15 I5--------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.215662 (delta = 0:00:00.001996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.216660 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------LENOVO YOGA 15 I5--------------------
# 2021-02-05 11:28:35.218653 (delta = 0:00:00.001993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес --------------LENOVO YOGA 15 I7--------------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.219649 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.220648 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  --------------LENOVO YOGA 15 I7--------------------
# 2021-02-05 11:28:35.223639 (delta = 0:00:00.002991) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO YOGA 15 I9-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.224639 (delta = 0:00:00.001000) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.225635 (delta = 0:00:00.000996) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO YOGA 15 I9-------------
# 2021-02-05 11:28:35.227628 (delta = 0:00:00.001993) 	 : 	 sozdaj_ssylki_na_tovary->get_url->write:
#         LOG STR:   Не получен адрес ----------------LENOVO YOGA 15 AMD-------------
#                 EXCEPTION :   Message: Tried to run command without establishing a connection
#
# 2021-02-05 11:28:35.228626 (delta = 0:00:00.000998) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   Собрал ссылки False
# 2021-02-05 11:28:35.229625 (delta = 0:00:00.000999) 	 : 	 run_scenario->get_all->write:
#         LOG STR:   !!!!!  что-то пошло не так при сборе ссылок на страницы товаров
#             Не получил страницу  ----------------LENOVO YOGA 15 AMD-------------
# 2021-02-05 11:28:35.231617 (delta = 0:00:00.001992) 	 : 	 get_all->flush_p->write:
#         LOG STR:   Пустой список продуктов. Нечего записыавть
# 2021-02-05 11:28:35.232615 (delta = 0:00:00.000998) 	 : 	 export_products_by_scenaries->execute_list_of_scenaries->write:
#         LOG STR:   -=OK!=-
# 2021-02-05 11:28:35.233612 (delta = 0:00:00.000997) 	 : 	 flush_p->flush_p->write:
#         LOG STR:   Пустой список продуктов. Нечего записыавть
