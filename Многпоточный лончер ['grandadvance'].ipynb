# %%
import main
main.run(['grandadvance'])
# Out:
# 2021-04-27 09:32:51.674530 (delta = 0:00:00.042008) 	 : 	 __init__->__init__->write:
#         LOG STR:   supplier_settings = <module 'suppliers.grandadvance' from 'C:\\Users\\onela\\OneDrive\\REPOS\\Aluf\\Aluf\\suppliers\\grandadvance\\__init__.py'>
# 2021-04-27 09:32:51.675532 (delta = 0:00:00.001002) 	 : 	 __init__->__init__->write:
#         LOG STR:  запустился класс grandadvance
# 2021-04-27 09:32:51.677532 (delta = 0:00:00.002000) 	 : 	 run->run->write:
#         LOG STR:
# 2021-04-27 09:32:57.295889 (delta = 0:00:05.618357) 	 : 	 run->get_url->write:
#         LOG STR:   Current URL: https://www.grandadvance.co.il/
# 2021-04-27 09:32:57.317918 (delta = 0:00:00.022029) 	 : 	 run->log_in->write:
#         LOG STR:  Залогиниваюсь
# 2021-04-27 09:32:57.318918 (delta = 0:00:00.001000) 	 : 	 log_in->find->write:
#         LOG STR:   Ищем element_locator: ('css selector', 'div.col-md-12.login button')
# 2021-04-27 09:32:58.005971 (delta = 0:00:00.687053) 	 : 	 log_in->find->write:
# ...
